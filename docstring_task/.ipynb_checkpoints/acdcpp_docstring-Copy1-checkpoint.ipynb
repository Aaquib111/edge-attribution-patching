# %%
import os
import sys
sys.path.append('..')
sys.path.append('../Automatic-Circuit-Discovery/')
sys.path.append('../tracr/')
import IPython
ipython = get_ipython()
if ipython is not None:
    ipython.magic('load_ext autoreload')
    ipython.magic('autoreload 2')
import torch as t
from torch import Tensor

from acdc.docstring.utils import get_all_docstring_things
device = t.device("cuda" if t.cuda.is_available() else "CPU")
print(device)
# Out:
# /tmp/ipykernel_1884/1528838084.py:9: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   ipython.magic('load_ext autoreload')
# /tmp/ipykernel_1884/1528838084.py:10: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   ipython.magic('autoreload 2')
# cuda

# %%
all_docstring_items = get_all_docstring_things(num_examples=40, seq_len=5, device=device, metric_name='docstring_metric', correct_incorrect_wandb=False)

tl_model = all_docstring_items.tl_model
validation_metric = all_docstring_items.validation_metric
validation_data = all_docstring_items.validation_data
validation_labels = all_docstring_items.validation_labels
validation_patch_data = all_docstring_items.validation_patch_data
test_metrics = all_docstring_items.test_metrics
test_data = all_docstring_items.test_data
test_labels = all_docstring_items.test_labels
test_patch_data = all_docstring_items.test_patch_data
# Out:
# Loaded pretrained model attn-only-4l into HookedTransformer
# Moving model to device:  cuda

# %%
def neg_abs_docstring_metric(logits):
    return -abs(test_metrics['docstring_metric'](logits))

# %%
from ACDCPPExperiment import ACDCPPExperiment
import numpy as np
THRESHOLDS = [0.243567]#np.logspace(-4, 1, num=20, base=5) # [0.0473844]
# I'm just using one threshold so I can move fast!

tl_model.reset_hooks()
RUN_NAME = 'acdcpp_best'
acdcpp_exp = ACDCPPExperiment(
    model=tl_model,
    clean_data=test_data,
    corr_data=test_patch_data,
    acdc_metric=neg_abs_docstring_metric,
    acdcpp_metric=test_metrics['docstring_metric'],
    thresholds=THRESHOLDS,
    run_name=RUN_NAME,
    verbose=False,
    attr_absolute_val=True,
    save_graphs_after=0,
    run_acdcpp=True,
    run_acdc=False,
    pruning_mode='edge',
    no_pruned_nodes_attr=1,
)

pruned_heads, num_passes, acdcpp_pruned_attrs, acdc_pruned_attrs, edges_after_acdcpp, edges_after_acdc = acdcpp_exp.run()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Edge pruning: 100%|██████████| 226/226 [00:00<00:00, 25294.54it/s]
#
# Edge pruning:   0%|          | 0/226 [00:00<?, ?it/s]
# Edge pruning:  23%|██▎       | 53/226 [00:00<00:00, 527.33it/s]
# Edge pruning: 100%|██████████| 226/226 [00:00<00:00, 962.71it/s]
#
# Edge pruning: 100%|██████████| 226/226 [00:00<00:00, 56312.76it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.40it/s]

# %%
acdcpp_pruned_attrs
# Out:
# {0.0473844: {'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 7]': -0.2686312794685364,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 2]': 0.00038782390765845776,
#   'blocks.3.hook_resid_post[:]blocks.0.hook_resid_pre[:]': 0.0,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 6]': -1.3909823894500732,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 1]': 0.0006507146754302084,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 2]': 0.02979740872979164,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 3]': 0.1296483278274536,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 1]': -4.59105140180327e-05,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 5]': 0.01853604055941105,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 6]': 0.04186607897281647,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 0]': 4.978184006176889e-05,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 0]': -1.2799153327941895,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 4]': -0.122599296271801,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 2]': 0.003425896866247058,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 7]': 0.02523728832602501,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 5]': -0.004644355271011591,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 7]': 0.00017601920990273356,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 5]': 3.194802411599085e-05,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 7]': 0.0003210565773770213,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 3]': -0.010266058146953583,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 0]': -0.0025281161069869995,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 1]': 0.005054498091340065,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 4]': 0.02627924084663391,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 6]': -0.0005833632894791663,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 2]': -0.006858035922050476,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 4]': 0.0037526111118495464,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 0]': 0.00068199064116925,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 3]': 0.035993438214063644,
#   'blocks.3.hook_resid_post[:]blocks.1.attn.hook_result[:, :, 6]': 1.671607606112957e-05,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 5]': -0.03959124907851219,
#   'blocks.3.hook_resid_post[:]blocks.0.attn.hook_result[:, :, 3]': 6.46600965410471e-05,
#   'blocks.3.hook_resid_post[:]blocks.3.attn.hook_result[:, :, 1]': 0.030588166788220406,
#   'blocks.3.hook_resid_post[:]blocks.2.attn.hook_result[:, :, 4]': 0.020355621352791786,
#   'blocks.3.attn.hook_v[:, :, 7]blocks.3.hook_v_input[:, :, 7]': -0.2135120928287506,
#   'blocks.3.attn.hook_v[:, :, 6]blocks.3.hook_v_input[:, :, 6]': -1.57542884349823,
#   'blocks.3.attn.hook_v[:, :, 5]blocks.3.hook_v_input[:, :, 5]': -0.030409246683120728,
#   'blocks.3.attn.hook_v[:, :, 4]blocks.3.hook_v_input[:, :, 4]': 0.05254923552274704,
#   'blocks.3.attn.hook_v[:, :, 3]blocks.3.hook_v_input[:, :, 3]': 0.11250115185976028,
#   'blocks.3.attn.hook_v[:, :, 2]blocks.3.hook_v_input[:, :, 2]': 0.023721054196357727,
#   'blocks.3.attn.hook_v[:, :, 1]blocks.3.hook_v_input[:, :, 1]': 0.04507947340607643,
#   'blocks.3.attn.hook_v[:, :, 0]blocks.3.hook_v_input[:, :, 0]': -1.3832917213439941,
#   'blocks.3.attn.hook_k[:, :, 7]blocks.3.hook_k_input[:, :, 7]': -0.08041031658649445,
#   'blocks.3.attn.hook_k[:, :, 6]blocks.3.hook_k_input[:, :, 6]': -1.1859585046768188,
#   'blocks.3.attn.hook_k[:, :, 5]blocks.3.hook_k_input[:, :, 5]': -0.11132923513650894,
#   'blocks.3.attn.hook_k[:, :, 4]blocks.3.hook_k_input[:, :, 4]': 0.10456899553537369,
#   'blocks.3.attn.hook_k[:, :, 3]blocks.3.hook_k_input[:, :, 3]': 0.02736928127706051,
#   'blocks.3.attn.hook_k[:, :, 2]blocks.3.hook_k_input[:, :, 2]': 0.020546607673168182,
#   'blocks.3.attn.hook_k[:, :, 1]blocks.3.hook_k_input[:, :, 1]': 0.03570891171693802,
#   'blocks.3.attn.hook_k[:, :, 0]blocks.3.hook_k_input[:, :, 0]': -1.3868155479431152,
#   'blocks.3.attn.hook_q[:, :, 7]blocks.3.hook_q_input[:, :, 7]': -0.09900560975074768,
#   'blocks.3.attn.hook_q[:, :, 6]blocks.3.hook_q_input[:, :, 6]': -1.0526574850082397,
#   'blocks.3.attn.hook_q[:, :, 5]blocks.3.hook_q_input[:, :, 5]': -0.02134404331445694,
#   'blocks.3.attn.hook_q[:, :, 4]blocks.3.hook_q_input[:, :, 4]': 0.011981080286204815,
#   'blocks.3.attn.hook_q[:, :, 3]blocks.3.hook_q_input[:, :, 3]': 0.03788108378648758,
#   'blocks.3.attn.hook_q[:, :, 2]blocks.3.hook_q_input[:, :, 2]': 0.02508472092449665,
#   'blocks.3.attn.hook_q[:, :, 1]blocks.3.hook_q_input[:, :, 1]': -0.02729874849319458,
#   'blocks.3.attn.hook_q[:, :, 0]blocks.3.hook_q_input[:, :, 0]': -1.566361427307129,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 2]': 0.013387314975261688,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.hook_resid_pre[:]': -0.1569681167602539,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 1]': -0.0006879317807033658,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 1]': -0.0021412663627415895,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 5]': -0.0021514492109417915,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 6]': 0.015268645249307156,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 0]': -0.02750668302178383,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 4]': -0.00443017203360796,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 2]': 0.005826770327985287,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 7]': 0.010938592255115509,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 5]': 0.0027616301085799932,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 7]': -0.003296834183856845,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 5]': -0.03449680656194687,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 7]': 0.0015093148685991764,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 3]': -6.31983857601881e-05,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 0]': -0.003086571581661701,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 1]': -0.01888815127313137,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 6]': -0.013735205866396427,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 2]': 0.022429538890719414,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 4]': -0.0011459363158792257,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 0]': 0.008783627301454544,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 3]': 0.005329582374542952,
#   'blocks.3.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 6]': 0.0004912316799163818,
#   'blocks.3.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 3]': -0.0024705519899725914,
#   'blocks.3.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 4]': 0.0017382703954353929,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 2]': 0.0025244508869946003,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.hook_resid_pre[:]': -0.8710578083992004,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 1]': -0.001666935975663364,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 1]': -0.04648013040423393,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 5]': -0.024170108139514923,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 6]': 0.006898554507642984,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 0]': -0.1692497283220291,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 4]': 0.004630899988114834,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 2]': 0.003400365589186549,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 7]': -0.004292960278689861,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 5]': 0.008899393491446972,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 7]': 0.0007359024602919817,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 5]': -0.14391271770000458,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 7]': -0.006027288734912872,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 3]': -0.015223998576402664,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 0]': 0.04481483995914459,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 1]': -0.010609847493469715,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 6]': -0.009348621591925621,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 2]': -0.015710052102804184,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 4]': 0.0011188709177076817,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 0]': -0.0045632049441337585,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 3]': 0.035690777003765106,
#   'blocks.3.hook_v_input[:, :, 6]blocks.1.attn.hook_result[:, :, 6]': -0.004154440946877003,
#   'blocks.3.hook_v_input[:, :, 6]blocks.0.attn.hook_result[:, :, 3]': -0.0020395624451339245,
#   'blocks.3.hook_v_input[:, :, 6]blocks.2.attn.hook_result[:, :, 4]': 2.1439394913613796e-05,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 2]': -0.01783522218465805,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.hook_resid_pre[:]': -0.009824305772781372,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 1]': -0.0009560376638546586,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 1]': 0.002480188151821494,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 5]': 0.012120585888624191,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 6]': 0.0017073540948331356,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 0]': -0.008983039297163486,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 4]': 0.0012543429620563984,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 2]': 0.0012376978993415833,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 7]': -0.003589687403291464,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 5]': -0.0018468932248651981,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 7]': 0.003726635593920946,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 5]': -0.004889233037829399,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 7]': 0.0012352175544947386,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 3]': -0.004906185902655125,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 0]': -0.003175012767314911,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 1]': 0.005981403402984142,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 6]': 0.00016028713434934616,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 2]': -0.00630129873752594,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 4]': 0.0009445440373383462,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 0]': -0.014102792367339134,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 3]': -0.010826613754034042,
#   'blocks.3.hook_v_input[:, :, 5]blocks.1.attn.hook_result[:, :, 6]': -0.00033666379749774933,
#   'blocks.3.hook_v_input[:, :, 5]blocks.0.attn.hook_result[:, :, 3]': -0.0013233607169240713,
#   'blocks.3.hook_v_input[:, :, 5]blocks.2.attn.hook_result[:, :, 4]': -0.002942523919045925,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 2]': 0.0052421810105443,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.hook_resid_pre[:]': 0.01772240921854973,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 1]': 0.0035882419906556606,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 1]': 0.006326672155410051,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 5]': -0.00473636481910944,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 6]': 7.743437890894711e-05,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 0]': 0.010175023227930069,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 4]': 0.0013151555322110653,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 2]': 0.0020254491828382015,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 7]': 0.0008783700177446008,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 5]': 0.0006307635921984911,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 7]': -0.0022304393351078033,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 5]': -0.0028403678443282843,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 7]': -0.0018158734310418367,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 3]': -0.0006442547310143709,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 0]': -0.004783628508448601,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 1]': -0.0014099848922342062,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 6]': -0.00020151393255218863,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 2]': 0.00288797402754426,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 4]': 0.00010829055099748075,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 0]': 0.0011910614557564259,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 3]': 0.012722568586468697,
#   'blocks.3.hook_v_input[:, :, 4]blocks.1.attn.hook_result[:, :, 6]': -0.0007862825877964497,
#   'blocks.3.hook_v_input[:, :, 4]blocks.0.attn.hook_result[:, :, 3]': -0.00038119807140901685,
#   'blocks.3.hook_v_input[:, :, 4]blocks.2.attn.hook_result[:, :, 4]': -0.0027083405293524265,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 2]': -0.005970060359686613,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.hook_resid_pre[:]': 0.044304028153419495,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 1]': 0.0008187289349734783,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 1]': -0.0012213895097374916,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 5]': 0.02206849493086338,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 6]': -0.006760148797184229,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 0]': -5.668308585882187e-05,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 4]': -0.00227236351929605,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 2]': -0.0008147144690155983,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 7]': 0.0028494547586888075,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 5]': -0.0019237035885453224,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 7]': 0.00034685322316363454,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 5]': 0.0029494864866137505,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 7]': 0.004411221016198397,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 3]': 0.006150765344500542,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 0]': -0.0006928276270627975,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 1]': 0.00026185810565948486,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 6]': -0.0001901911455206573,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 2]': 0.001936089713126421,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 4]': -0.004403604194521904,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 0]': 0.0075406236574053764,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 3]': 0.02325410768389702,
#   'blocks.3.hook_v_input[:, :, 3]blocks.1.attn.hook_result[:, :, 6]': -0.0009131929837167263,
#   'blocks.3.hook_v_input[:, :, 3]blocks.0.attn.hook_result[:, :, 3]': -0.0027198465541005135,
#   'blocks.3.hook_v_input[:, :, 3]blocks.2.attn.hook_result[:, :, 4]': 0.001977592706680298,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 2]': 1.2356205843389034e-05,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.hook_resid_pre[:]': 1.752040407154709e-05,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 1]': -0.00150708993896842,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 1]': 9.3666254542768e-05,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 5]': 0.0040286146104335785,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 6]': -0.005102373659610748,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 0]': -0.0001649757323320955,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 4]': 0.018739286810159683,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 2]': 9.892130037769675e-05,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 7]': -0.005029435269534588,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 5]': 0.00012757256627082825,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 7]': -0.00019550086290109903,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 5]': 2.0383195078466088e-05,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 7]': 3.374178777448833e-05,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 3]': -0.0003404887393116951,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 0]': 0.0004527357523329556,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 1]': -0.003064565360546112,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 6]': 0.0006967352237552404,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 2]': 0.0022493815049529076,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 4]': -0.0005471756448969245,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 0]': 0.0011566688772290945,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 3]': 0.002213579136878252,
#   'blocks.3.hook_v_input[:, :, 2]blocks.1.attn.hook_result[:, :, 6]': 0.0013286832254379988,
#   'blocks.3.hook_v_input[:, :, 2]blocks.0.attn.hook_result[:, :, 3]': 0.00034470384707674384,
#   'blocks.3.hook_v_input[:, :, 2]blocks.2.attn.hook_result[:, :, 4]': 0.0027471964713186026,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 2]': 0.001048303791321814,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.hook_resid_pre[:]': -0.0011518389219418168,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 1]': 0.0026082939002662897,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 1]': -0.00018061963783111423,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 5]': 0.0011666413629427552,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 6]': -0.002319927327334881,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 0]': -0.0003617172478698194,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 4]': 0.02009308710694313,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 2]': -0.0011065443977713585,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 7]': 0.005451472941786051,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 5]': 0.0020549457985907793,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 7]': 3.7918151065241545e-05,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 5]': -0.0006925578927621245,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 7]': -0.0005103808944113553,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 3]': 9.232200682163239e-06,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 0]': 0.02423284389078617,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 1]': -0.007381956093013287,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 6]': -0.00038883736124262214,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 2]': -0.003862714860588312,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 4]': -0.0013844093773514032,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 0]': 0.009142507798969746,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 3]': -0.011707129888236523,
#   'blocks.3.hook_v_input[:, :, 1]blocks.1.attn.hook_result[:, :, 6]': 0.00015093712136149406,
#   'blocks.3.hook_v_input[:, :, 1]blocks.0.attn.hook_result[:, :, 3]': -0.0005701669142581522,
#   'blocks.3.hook_v_input[:, :, 1]blocks.2.attn.hook_result[:, :, 4]': -0.001811410766094923,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 2]': 0.030286036431789398,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.hook_resid_pre[:]': -0.7506502866744995,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 1]': -0.00045679177856072783,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 1]': -0.06231730058789253,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 5]': -0.013103951700031757,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 6]': 0.010855387896299362,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 0]': -0.06317044794559479,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 4]': -0.0008478926029056311,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 2]': 0.00023395614698529243,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 7]': 0.0005287656094878912,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 5]': -0.0015583867207169533,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 7]': -0.010974251665174961,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 5]': -0.24037395417690277,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 7]': 0.016880957409739494,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 3]': -0.0014126007445156574,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 0]': 0.03800084441900253,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 1]': -0.00039162812754511833,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 6]': -0.011160103604197502,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 2]': 0.026816535741090775,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 4]': -0.0001812841510400176,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 0]': -0.0593436062335968,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 3]': 0.01727914623916149,
#   'blocks.3.hook_v_input[:, :, 0]blocks.1.attn.hook_result[:, :, 6]': -0.0021062446758151054,
#   'blocks.3.hook_v_input[:, :, 0]blocks.0.attn.hook_result[:, :, 3]': -0.002881042892113328,
#   'blocks.3.hook_v_input[:, :, 0]blocks.2.attn.hook_result[:, :, 4]': -0.001983568537980318,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 2]': 0.03431970998644829,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.hook_resid_pre[:]': -0.05366068333387375,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 1]': 0.0020619872957468033,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 1]': 0.006151278503239155,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 5]': 0.009085774421691895,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 6]': -0.007181401830166578,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 0]': 0.03243693709373474,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 4]': 0.0005543725565075874,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 2]': 0.000169009726960212,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 7]': 0.00045607401989400387,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 5]': -0.0002787672565318644,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 7]': -0.0013903091894462705,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 5]': 0.031812798231840134,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 7]': -0.010105423629283905,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 3]': -0.0030593867413699627,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 0]': -0.00739589286968112,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 1]': -0.002885156311094761,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 6]': 0.0030565066263079643,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 2]': 0.015992313623428345,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 4]': -0.0015398460673168302,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 0]': -0.0008797119371592999,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 3]': 0.0060061002150177956,
#   'blocks.3.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 6]': -0.004648836329579353,
#   'blocks.3.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 3]': -0.0034993637818843126,
#   'blocks.3.hook_k_input[:, :, 7]blocks.2.attn.hook_result[:, :, 4]': 0.005627346225082874,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 2]': -0.08166652917861938,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.hook_resid_pre[:]': 1.8925707340240479,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 1]': 0.02676139399409294,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 1]': 0.0062571801245212555,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 5]': 0.3934677243232727,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 6]': 0.007397348526865244,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 0]': 0.22200286388397217,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 4]': 0.008200321346521378,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 2]': 0.02712421305477619,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 7]': 0.017297660931944847,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 5]': 0.050967954099178314,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 7]': 0.05608111247420311,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 5]': 0.2816368341445923,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 7]': 0.05248623341321945,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 3]': 0.021377628669142723,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 0]': -0.3878682851791382,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 1]': 0.004134773276746273,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 6]': 0.009607885032892227,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 2]': -0.088981032371521,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 4]': -0.00040139537304639816,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 0]': 0.07484418898820877,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 3]': 0.37262028455734253,
#   'blocks.3.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 6]': 0.01981261372566223,
#   'blocks.3.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 3]': 0.0224259402602911,
#   'blocks.3.hook_k_input[:, :, 6]blocks.2.attn.hook_result[:, :, 4]': 0.009258883073925972,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 2]': -0.035144440829753876,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.hook_resid_pre[:]': -0.013693451881408691,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 1]': -0.0076393429189920425,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 1]': -0.026403989642858505,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 5]': 0.0210089273750782,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 6]': -0.011940574273467064,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 0]': -0.03556870296597481,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 4]': 0.003433596808463335,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 2]': 0.00613030232489109,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 7]': -0.004492521286010742,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 5]': -0.00026856083422899246,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 7]': 0.0044294968247413635,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 5]': 0.04985416680574417,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 7]': -0.016488319262862206,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 3]': 0.006199995521456003,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 0]': 0.008357379585504532,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 1]': 0.0012392897624522448,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 6]': -0.002972278743982315,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 2]': 0.014724453911185265,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 4]': -7.279100827872753e-05,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 0]': -0.0036527938209474087,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 3]': -0.0007037858013063669,
#   'blocks.3.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 6]': -9.393703658133745e-05,
#   'blocks.3.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 3]': 0.005699078552424908,
#   'blocks.3.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 4]': 0.005918416194617748,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 2]': -0.0017310327384620905,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.hook_resid_pre[:]': 0.04326922073960304,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 1]': 0.00411127507686615,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 1]': 0.0006614265730604529,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 5]': -0.00509028322994709,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 6]': -0.00042443396523594856,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 0]': 0.007745329290628433,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 4]': -0.006552351173013449,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 2]': 0.005923204589635134,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 7]': -0.000582755368668586,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 5]': 0.0013178789522498846,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 7]': 0.007235025987029076,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 5]': 0.025476014241576195,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 7]': 0.0033464140724390745,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 3]': -0.00013557641068473458,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 0]': -0.010576698929071426,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 1]': -0.004419908858835697,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 6]': -0.008732032030820847,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 2]': 0.010041560046374798,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 4]': -0.0005450173048302531,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 0]': 0.005818097852170467,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 3]': -0.002174840308725834,
#   'blocks.3.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 6]': -0.0012819406110793352,
#   'blocks.3.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 3]': 0.00016546130063943565,
#   'blocks.3.hook_k_input[:, :, 4]blocks.2.attn.hook_result[:, :, 4]': 0.0017891476163640618,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 2]': -0.02810470573604107,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.hook_resid_pre[:]': 0.03217243403196335,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 1]': -0.0062116170302033424,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 1]': -0.0034738057292997837,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 5]': 0.002077575773000717,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 6]': -0.010046551935374737,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 0]': -0.007122666109353304,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 4]': 0.006130814086645842,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 2]': -0.00029255470144562423,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 7]': 0.008545965887606144,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 5]': 0.001301448093727231,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 7]': 0.0010649638716131449,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 5]': -0.014782242476940155,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 7]': 0.0032167863100767136,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 3]': -0.0018537885043770075,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 0]': -0.009051887318491936,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 1]': -0.0054349759593605995,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 6]': -0.0001837335294112563,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 2]': 0.012940575368702412,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 4]': -0.0007032303838059306,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 0]': 0.004568304866552353,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 3]': -0.010599122382700443,
#   'blocks.3.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 6]': -0.0028294669464230537,
#   'blocks.3.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 3]': 4.477798938751221e-05,
#   'blocks.3.hook_k_input[:, :, 3]blocks.2.attn.hook_result[:, :, 4]': 0.003841439727693796,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 2]': 0.0015301984967663884,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.hook_resid_pre[:]': 5.296897143125534e-06,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 1]': 0.0005518805701285601,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 1]': 6.82265090290457e-05,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 5]': -0.004581782966852188,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 6]': 0.004015270620584488,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 0]': -3.928648948203772e-05,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 4]': 0.01186593808233738,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 2]': 0.0004173710767645389,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 7]': -0.002902739215642214,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 5]': 0.0007824610220268369,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 7]': -0.00016778780263848603,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 5]': -0.0008121202699840069,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 7]': -0.000122919213026762,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 3]': 0.0003711579483933747,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 0]': -0.00010192752233706415,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 1]': -0.00015370442997664213,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 6]': -0.0007137401262298226,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 2]': -0.0006379451951943338,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 4]': 0.00011993895168416202,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 0]': 0.00027214718284085393,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 3]': -0.0020924508571624756,
#   'blocks.3.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 6]': -0.000638052704744041,
#   'blocks.3.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 3]': 0.00014100736007094383,
#   'blocks.3.hook_k_input[:, :, 2]blocks.2.attn.hook_result[:, :, 4]': 0.00301185785792768,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 2]': 0.001374389510601759,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.hook_resid_pre[:]': -0.001273377682082355,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 1]': 0.0047672707587480545,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 1]': 0.0002821683883666992,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 5]': -0.0008011966710910201,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 6]': 0.011186576448380947,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 0]': -0.001280767610296607,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 4]': -0.0029786131344735622,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 2]': -0.0002041306288447231,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 7]': -0.000255350285442546,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 5]': -0.0036731010768562555,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 7]': -0.00030543189495801926,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 5]': 0.0008624712354503572,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 7]': -0.0012294379994273186,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 3]': 0.0017397699411958456,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 0]': -0.039707284420728683,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 1]': -0.00196535000577569,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 6]': 0.0003097830922342837,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 2]': 0.009268458932638168,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 4]': 0.0005939517286606133,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 0]': -0.002115590963512659,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 3]': -0.013034520670771599,
#   'blocks.3.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 6]': -0.0007584787672385573,
#   'blocks.3.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 3]': 0.00024556912831030786,
#   'blocks.3.hook_k_input[:, :, 1]blocks.2.attn.hook_result[:, :, 4]': -0.0010624208953231573,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 2]': -0.08758727461099625,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.hook_resid_pre[:]': 2.6085264682769775,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 1]': -0.05240677297115326,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 1]': 0.1011284589767456,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 5]': 0.408697247505188,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 6]': -0.07742902636528015,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 0]': 0.2637133002281189,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 4]': 0.008647718466818333,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 2]': -0.003669165074825287,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 7]': -0.04945390298962593,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 5]': 0.010700534097850323,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 7]': 0.05540717393159866,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 5]': 0.7215601801872253,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 7]': 0.0586995892226696,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 3]': 0.02593507431447506,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 0]': -0.7201820611953735,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 1]': 0.029145896434783936,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 6]': -0.017142415046691895,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 2]': -0.03909631073474884,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 4]': -0.007762032561004162,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 0]': 0.019427254796028137,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 3]': 0.38050225377082825,
#   'blocks.3.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 6]': 0.05040992796421051,
#   'blocks.3.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 3]': -0.023716457188129425,
#   'blocks.3.hook_k_input[:, :, 0]blocks.2.attn.hook_result[:, :, 4]': 0.00681997649371624,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 2]': 0.0008301495108753443,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.hook_resid_pre[:]': 0.0,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 1]': 0.0017539496766403317,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 1]': -1.809468085411936e-05,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 5]': -0.00844294298440218,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 6]': -0.008669491857290268,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 0]': 7.629940955666825e-05,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 4]': -0.04549684375524521,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 2]': 0.0003298431693110615,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 7]': 0.003035578178241849,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 5]': 0.0006937713478691876,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 7]': 3.248567372793332e-05,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 5]': 0.000115725546493195,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 7]': 0.0012550171231850982,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 3]': -0.0007296477560885251,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 0]': -0.002684543374925852,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 1]': -0.004549893084913492,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 6]': -7.178052328526974e-05,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 2]': 0.012051481753587723,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 4]': 5.867099389433861e-05,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 0]': -0.0003936951397918165,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 3]': -0.03370418772101402,
#   'blocks.3.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 6]': 2.485426375642419e-05,
#   'blocks.3.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 3]': -0.00022649076709058136,
#   'blocks.3.hook_q_input[:, :, 7]blocks.2.attn.hook_result[:, :, 4]': 0.0034065721556544304,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 2]': -0.005045012105256319,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.hook_resid_pre[:]': 0.0,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 1]': -0.004308643750846386,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 1]': -0.00016293904627673328,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 5]': -0.014676392078399658,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 6]': -0.05842321366071701,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 0]': -0.0005315435118973255,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 4]': -1.1747957468032837,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 2]': -0.012956812977790833,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 7]': -0.012814360670745373,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 5]': -0.02958998642861843,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 7]': -3.388595359865576e-05,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 5]': -0.00025084539083763957,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 7]': -0.0037816097028553486,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 3]': 0.0016126615228131413,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 0]': -0.07669459283351898,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 1]': -0.02413271926343441,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 6]': 8.097650425042957e-05,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 2]': 0.5800099968910217,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 4]': -0.007381355855613947,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 0]': -0.0024148705415427685,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 3]': -0.10209167003631592,
#   'blocks.3.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 6]': 0.0007125296979211271,
#   'blocks.3.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 3]': -0.0014686000067740679,
#   'blocks.3.hook_q_input[:, :, 6]blocks.2.attn.hook_result[:, :, 4]': -0.007843255996704102,
#   'blocks.3.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 2]': -0.00043547595851123333,
#   'blocks.3.hook_q_input[:, :, 5]blocks.0.hook_resid_pre[:]': 0.0,
#   'blocks.3.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 1]': 0.0006539571913890541,
#   'blocks.3.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 1]': 5.557537224376574e-05,
#   'blocks.3.hook_q_input[:, :, 5]blocks.2.attn.hook_result[:, :, 5]': -0.002842528745532036,
#   'blocks.3.hook_q_input[:, :, 5]blocks.2.attn.hook_result[:, :, 6]': -0.0004155184142291546,
#   'blocks.3.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 0]': 4.4045613321941346e-05,
#   'blocks.3.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 4]': -0.020422767847776413,
#   'blocks.3.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 2]': 0.0006762573029845953,
#   'blocks.3.hook_q_input[:, :, 5]blocks.2.attn.hook_result[:, :, 7]': -0.0005872383480891585,
#   'blocks.3.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 5]': -0.007422195747494698,
#   'blocks.3.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 7]': -1.9958870325353928e-05,
#   'blocks.3.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 5]': 3.2322372135240585e-05,
#   'blocks.3.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 7]': -9.070863598026335e-05,
#   'blocks.3.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 3]': 0.0003280384698882699,
# ...
#   'blocks.2.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 1]': 0.005799822974950075,
#   'blocks.2.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 6]': -0.00399172306060791,
#   'blocks.2.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 1]': 0.0002889767347369343,
#   'blocks.2.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 3]': -1.0016752639785409e-05,
#   'blocks.2.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 5]': 0.00020800612401217222,
#   'blocks.2.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 0]': -0.004583580419421196,
#   'blocks.2.hook_k_input[:, :, 7]blocks.1.attn.hook_result[:, :, 3]': -0.0007496137986890972,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 2]': -0.0069495816715061665,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 7]': 0.0030302407685667276,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 4]': 0.04396364092826843,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 6]': -0.003366882912814617,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 5]': 0.01602896675467491,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.hook_resid_pre[:]': 0.07175911962985992,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 4]': -0.0031484770588576794,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 2]': -0.0010767142521217465,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 0]': -0.010567069053649902,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 7]': 0.0010470401030033827,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 1]': 0.004292747471481562,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 6]': -0.001339861424639821,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 1]': 0.0035435424651950598,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 3]': -0.003501447383314371,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 5]': 0.0022440245375037193,
#   'blocks.2.hook_k_input[:, :, 6]blocks.0.attn.hook_result[:, :, 0]': 0.011722957715392113,
#   'blocks.2.hook_k_input[:, :, 6]blocks.1.attn.hook_result[:, :, 3]': -0.0016492819413542747,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 2]': 0.013254934921860695,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 7]': -0.012913700193166733,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 4]': 0.03624029457569122,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 6]': -0.006298290565609932,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 5]': -0.07748425751924515,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.hook_resid_pre[:]': -0.2406052052974701,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 4]': -0.007253739517182112,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 2]': 0.009974995627999306,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 0]': 0.004143818281590939,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 7]': -0.003367491066455841,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 1]': -0.0030294107273221016,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 6]': -0.009422525763511658,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 1]': -0.015457995235919952,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 3]': 0.0005999559070914984,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 5]': 0.001376311294734478,
#   'blocks.2.hook_k_input[:, :, 5]blocks.0.attn.hook_result[:, :, 0]': -0.054783452302217484,
#   'blocks.2.hook_k_input[:, :, 5]blocks.1.attn.hook_result[:, :, 3]': -0.004609713330864906,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 2]': -0.0006583909271284938,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 7]': 0.0006148288957774639,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 4]': 0.11618572473526001,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 6]': -0.0002328116534044966,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 5]': -0.002623368985950947,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.hook_resid_pre[:]': -0.009992115199565887,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 4]': -0.0005886534927412868,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 2]': 0.00014470203313976526,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 0]': 0.002463478595018387,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 7]': 8.144737512338907e-05,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 1]': 0.000111444853246212,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 6]': 2.7301139198243618e-05,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 1]': -0.001284064375795424,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 3]': -0.00044087093556299806,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 5]': 0.0031178114004433155,
#   'blocks.2.hook_k_input[:, :, 4]blocks.0.attn.hook_result[:, :, 0]': 0.0003041151794604957,
#   'blocks.2.hook_k_input[:, :, 4]blocks.1.attn.hook_result[:, :, 3]': -0.0005033462657593191,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 2]': 0.035054899752140045,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 7]': -0.0039214398711919785,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 4]': -0.006831910461187363,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 6]': -0.008431173861026764,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 5]': -0.034034647047519684,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.hook_resid_pre[:]': -0.058061495423316956,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 4]': 0.00281956372782588,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 2]': -0.0032647247426211834,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 0]': -0.002336223842576146,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 7]': -0.0061639705672860146,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 1]': 0.002919703722000122,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 6]': 0.003392630722373724,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 1]': 0.020035428926348686,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 3]': 0.00810651108622551,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 5]': -0.007569196168333292,
#   'blocks.2.hook_k_input[:, :, 3]blocks.0.attn.hook_result[:, :, 0]': -0.021257661283016205,
#   'blocks.2.hook_k_input[:, :, 3]blocks.1.attn.hook_result[:, :, 3]': -0.005438799504190683,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 2]': -0.028904058039188385,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 7]': 0.0030734215397387743,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 4]': 0.22214999794960022,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 6]': 0.002545227063819766,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 5]': -0.010703081265091896,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.hook_resid_pre[:]': 0.05054512247443199,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 4]': -0.004947246517986059,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 2]': 0.0025558595079928637,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 0]': 0.09911404550075531,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 7]': -0.0057505052536726,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 1]': 0.02239558845758438,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 6]': -0.0006227351259440184,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 1]': 0.006159854121506214,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 3]': 0.0006909789517521858,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 5]': -0.0033449018374085426,
#   'blocks.2.hook_k_input[:, :, 2]blocks.0.attn.hook_result[:, :, 0]': 0.020731862634420395,
#   'blocks.2.hook_k_input[:, :, 2]blocks.1.attn.hook_result[:, :, 3]': 0.003908551298081875,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 2]': 0.0018676393665373325,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 7]': -0.0004855781444348395,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 4]': 0.00040625594556331635,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 6]': -0.004508559126406908,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 5]': 0.007083923555910587,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.hook_resid_pre[:]': -0.059390321373939514,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 4]': 0.0023539243265986443,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 2]': 0.004680477548390627,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 0]': -0.002931964583694935,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 7]': -0.003335433080792427,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 1]': 0.006851195823401213,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 6]': -0.00024053067318163812,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 1]': 0.0025721313431859016,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 3]': 0.004288211464881897,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 5]': 0.001354046631604433,
#   'blocks.2.hook_k_input[:, :, 1]blocks.0.attn.hook_result[:, :, 0]': -0.004418388940393925,
#   'blocks.2.hook_k_input[:, :, 1]blocks.1.attn.hook_result[:, :, 3]': -0.0003786332381423563,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 2]': 7.617357186973095e-05,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 7]': -0.004215771332383156,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 4]': 0.06398147344589233,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 6]': -0.00027151755057275295,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 5]': -0.0864238440990448,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.hook_resid_pre[:]': -1.036901831626892,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 4]': 0.010567206889390945,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 2]': -0.03259597718715668,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 0]': -0.016807958483695984,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 7]': -0.012745222076773643,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 1]': -0.004874737933278084,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 6]': -0.004147436935454607,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 1]': -0.03404463455080986,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 3]': 0.008850952610373497,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 5]': 0.01762724108994007,
#   'blocks.2.hook_k_input[:, :, 0]blocks.0.attn.hook_result[:, :, 0]': -0.06789637356996536,
#   'blocks.2.hook_k_input[:, :, 0]blocks.1.attn.hook_result[:, :, 3]': -0.00017618853598833084,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 2]': -0.009482926689088345,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 7]': 0.0010791883105412126,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 4]': -0.002703891135752201,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 6]': -0.004899957217276096,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 5]': 0.013838143087923527,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.hook_resid_pre[:]': 0.053907185792922974,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 4]': -0.0011479135137051344,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 2]': 0.011019866913557053,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 0]': 0.026372311636805534,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 7]': -0.004557686857879162,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 1]': -0.0021294099278748035,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 6]': 0.0033871950581669807,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 1]': 0.007221639156341553,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 3]': 0.0009973261039704084,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 5]': -0.002183696487918496,
#   'blocks.2.hook_q_input[:, :, 7]blocks.0.attn.hook_result[:, :, 0]': 0.00242684711702168,
#   'blocks.2.hook_q_input[:, :, 7]blocks.1.attn.hook_result[:, :, 3]': 0.005254082381725311,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 2]': 0.0160685945302248,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 7]': 0.0007864204817451537,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 4]': 0.005430626682937145,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 6]': 0.0008662848267704248,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 5]': -0.02005026489496231,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.hook_resid_pre[:]': -0.053634315729141235,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 4]': -0.003468654118478298,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 2]': -0.0128882871940732,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 0]': -0.01626410335302353,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 7]': 0.011559903621673584,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 1]': 0.020602716132998466,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 6]': -0.0006687035784125328,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 1]': -0.02128192037343979,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 3]': 0.004134983755648136,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 5]': -0.0006836537504568696,
#   'blocks.2.hook_q_input[:, :, 6]blocks.0.attn.hook_result[:, :, 0]': -0.013155682012438774,
#   'blocks.2.hook_q_input[:, :, 6]blocks.1.attn.hook_result[:, :, 3]': 0.005068196449428797,
#   'blocks.2.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 2]': -0.010300176218152046,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 7]': 0.0009556603617966175,
#   'blocks.2.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 4]': 0.0008399486541748047,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 6]': 0.007850274443626404,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 5]': -0.007582280784845352,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.hook_resid_pre[:]': -0.142005056142807,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 4]': -0.0007436573505401611,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 2]': -0.003584455233067274,
#   'blocks.2.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 0]': -0.007395011372864246,
#   'blocks.2.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 7]': 0.007498742081224918,
#   'blocks.2.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 1]': 0.017575841397047043,
#   'blocks.2.hook_q_input[:, :, 5]blocks.1.attn.hook_result[:, :, 6]': 0.010698317550122738,
#   'blocks.2.hook_q_input[:, :, 5]blocks.0.attn.hook_result[:, :, 1]': -0.016201825812458992,
#   ...}}

# %%
import numpy as np
np.quantile(list(acdcpp_pruned_attrs[0.5].values()), [0, 0.25, 0.5, 0.75, 0.9, 1])
# Out:
# array([0.00000000e+00, 1.14791351e-03, 4.88377968e-03, 1.94272548e-02,
#        7.03021973e-02, 4.55413342e+00])

# %%
import json
with open(f'{RUN_NAME}_acdcpp_scores.json', 'w') as f:
    json.dump(acdcpp_pruned_attrs, f)

# %%
import json
with open(f'{RUN_NAME}_acdc_scores.json', 'w') as f:
    json.dump(acdc_pruned_attrs, f)
with open(f'{RUN_NAME}_num_passes.json', 'w') as f:
    json.dump(num_passes, f)

# %%
import json

cleaned_pp_attrs = {}
for thresh in acdcpp_pruned_attrs.keys():
    cleaned_pp_attrs[thresh] = {}
    for (parent, child), attr in acdcpp_pruned_attrs[thresh].items():
        cleaned_pp_attrs[thresh]\
        [f'{child.hook_point_name}{child.replace_parens(child.index)}{parent.hook_point_name}{parent.replace_parens(parent.index)}'] = attr

with open(f'{RUN_NAME}_acdc_pruned_attrs.json', 'w') as f:
    json.dump(cleaned_pp_attrs, f)

# %%
import json

for thresh in pruned_heads.keys():
    pruned_heads[thresh][0] = list(pruned_heads[thresh][0])
    pruned_heads[thresh][1] = list(pruned_heads[thresh][1])
    
cleaned_pp_attrs = {}
for thresh in acdcpp_pruned_attrs.keys():
    cleaned_pp_attrs[thresh] = {}
    for (parent, child), attr in acdcpp_pruned_attrs[thresh].items():
        cleaned_pp_attrs[thresh]\
        [f'{child.hook_point_name}{child.replace_parens(child.index)}{parent.hook_point_name}{parent.replace_parens(parent.index)}'] = attr
        
# Cleaning the edges
for thresh in edges_after_acdcpp.keys():
    edges_after_acdcpp[thresh] = list(edges_after_acdcpp[thresh])
    edges_after_acdc[thresh] = list(edges_after_acdc[thresh])
    
APPEND = False

if APPEND:
    with open(f'{RUN_NAME}_pruned_heads.json', 'r') as f:
        old_pruned_heads = json.load(f)
    with open(f'{RUN_NAME}_acdcpp_pruned_attrs.json', 'r') as f:
        old_acdcpp_pruned_attrs = json.load(f)
    with open(f'{RUN_NAME}_acdc_pruned_attrs.json', 'r') as f:
        old_acdc_pruned_attrs = json.load(f)
    with open(f'{RUN_NAME}_num_passes.json', 'r') as f:
        old_num_passes = json.load(f)
    with open(f'{RUN_NAME}_edges_after_acdcpp.json', 'r') as f:
        old_edges_after_acdcpp = json.load(f)
    with open(f'{RUN_NAME}_edges_after_acdc.json', 'r') as f:
        old_edges_after_acdc = json.load(f)
    
    pruned_heads = pruned_heads.update(old_pruned_heads)
    cleaned_pp_attrs = cleaned_pp_attrs.update(old_acdcpp_pruned_attrs)
    acdc_pruned_attrs = acdc_pruned_attrs.update(old_acdc_pruned_attrs)
    num_passes = num_passes.update(old_num_passes)
    edges_after_acdcpp = edges_after_acdcpp.update(old_edges_after_acdcpp)
    edges_after_acdc = edges_after_acdc.update(old_edges_after_acdc)

with open(f'{RUN_NAME}_pruned_heads.json', 'w') as f:
    json.dump(pruned_heads, f)
with open(f'{RUN_NAME}_num_passes.json', 'w') as f:
    json.dump(num_passes, f)
with open(f'{RUN_NAME}_acdcpp_pruned_attrs.json', 'w') as f:
    json.dump(cleaned_pp_attrs, f)
with open(f'{RUN_NAME}_acdc_pruned_attrs.json', 'w') as f:
    json.dump(acdc_pruned_attrs, f)

with open(f'{RUN_NAME}_edges_after_acdcpp.json', 'w') as f:
    json.dump(edges_after_acdcpp, f)
with open(f'{RUN_NAME}_edges_after_acdc.json', 'w') as f:
    json.dump(edges_after_acdc, f)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 17
#      15 for thresh in edges_after_acdcpp.keys():
#      16     edges_after_acdcpp[thresh] = list(edges_after_acdcpp[thresh])
# ---> 17     edges_after_acdc[thresh] = list(edges_after_acdc[thresh])
#      19 APPEND = False
#      21 if APPEND:
#
# KeyError: 0.00032
