# %%
import os
import sys
sys.path.append('..')
sys.path.append('../Automatic-Circuit-Discovery/')

import torch as t
from torch import Tensor

from acdc.docstring.utils import get_all_docstring_things
device = t.device("cuda" if t.cuda.is_available() else "CPU")
print(device)
# Out:
# cuda

# %%
all_docstring_items, batched_prompts  = get_all_docstring_things(num_examples=40, seq_len=5, device=device, metric_name='docstring_metric', correct_incorrect_wandb=False)

tl_model = all_docstring_items.tl_model
validation_metric = all_docstring_items.validation_metric
validation_data = all_docstring_items.validation_data
validation_labels = all_docstring_items.validation_labels
validation_patch_data = all_docstring_items.validation_patch_data
test_metrics = all_docstring_items.test_metrics
test_data = all_docstring_items.test_data
test_labels = all_docstring_items.test_labels
test_patch_data = all_docstring_items.test_patch_data
# Out:
# Loaded pretrained model attn-only-4l into HookedTransformer
# Moving model to device:  cuda

# %%
def abs_docstring_metric(logits):
    return -abs(test_metrics['docstring_metric'](logits))

# %%
from ACDCPPExperiment import ACDCPPExperiment
import numpy as np
THRESHOLDS = np.arange(0.005, 0.16, 0.005)
RUN_NAME = 'abs_value'
acdcpp_exp = ACDCPPExperiment(tl_model,
                              test_data,
                              test_patch_data,
                              test_metrics['docstring_metric'],
                              abs_docstring_metric,
                              THRESHOLDS,
                              run_name=RUN_NAME,
                              verbose=False,
                              attr_absolute_val=True,
                              save_graphs_after=0,
                             )
pruned_heads, num_passes, pruned_attrs = acdcpp_exp.run()
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
# /root/acdcpp/docstring_task/../Automatic-Circuit-Discovery/acdc/TLACDCExperiment.py:769: UserWarning: Finished iterating
#   warnings.warn("Finished iterating")
# Saving ACDC Graph
#   3%|▎         | 1/31 [06:46<3:23:10, 406.35s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
# Saving ACDC Graph
#   6%|▋         | 2/31 [11:13<2:36:53, 324.60s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
# Saving ACDC Graph
#  10%|▉         | 3/31 [14:38<2:05:57, 269.92s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  13%|█▎        | 4/31 [17:43<1:46:19, 236.29s/it]
# Saving ACDC Graph
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  16%|█▌        | 5/31 [20:15<1:29:14, 205.95s/it]
# Saving ACDC Graph
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  19%|█▉        | 6/31 [22:27<1:15:23, 180.95s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  23%|██▎       | 7/31 [24:14<1:02:40, 156.70s/it]
# Saving ACDC Graph
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  26%|██▌       | 8/31 [25:38<51:07, 133.36s/it]  WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
# Saving ACDC Graph
#  29%|██▉       | 9/31 [26:53<42:14, 115.20s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  32%|███▏      | 10/31 [28:05<35:39, 101.89s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
# Saving ACDC Graph
#  35%|███▌      | 11/31 [29:17<30:54, 92.71s/it] WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  39%|███▊      | 12/31 [30:24<26:55, 85.00s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  42%|████▏     | 13/31 [31:33<24:03, 80.17s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  45%|████▌     | 14/31 [32:39<21:30, 75.89s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  48%|████▊     | 15/31 [33:41<19:05, 71.59s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  52%|█████▏    | 16/31 [34:40<16:55, 67.69s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  55%|█████▍    | 17/31 [35:37<15:03, 64.54s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  58%|█████▊    | 18/31 [36:30<13:16, 61.28s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  61%|██████▏   | 19/31 [37:23<11:45, 58.75s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  65%|██████▍   | 20/31 [38:13<10:17, 56.13s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  68%|██████▊   | 21/31 [39:00<08:53, 53.36s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  71%|███████   | 22/31 [39:43<07:31, 50.14s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  74%|███████▍  | 23/31 [40:24<06:18, 47.36s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  77%|███████▋  | 24/31 [41:04<05:16, 45.16s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  81%|████████  | 25/31 [41:44<04:21, 43.60s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  84%|████████▍ | 26/31 [42:23<03:31, 42.21s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  87%|████████▋ | 27/31 [43:02<02:45, 41.35s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  90%|█████████ | 28/31 [43:37<01:58, 39.52s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  94%|█████████▎| 29/31 [44:11<01:15, 37.80s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
#  97%|█████████▋| 30/31 [44:43<00:35, 35.97s/it]WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Saving ACDC Graph
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.3.hook_resid_post
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.3.hook_resid_post, [:])
# Saving ACDC++ Graph
# 100%|██████████| 31/31 [45:15<00:00, 87.59s/it]
# Saving ACDC Graph

# %%
import json

for thresh in pruned_heads.keys():
   pruned_heads[thresh][0] = list(pruned_heads[thresh][0])
   pruned_heads[thresh][1] = list(pruned_heads[thresh][1])

cleaned_attrs = {}
for thresh in pruned_attrs.keys():
    cleaned_attrs[thresh] = {}
    for (layer, head), attr in pruned_attrs[thresh].items():
        cleaned_attrs[thresh][f'L{layer}H{head}'] = attr
        
with open(f'{RUN_NAME}_pruned_heads_docstring.json', 'w') as f:
    json.dump(pruned_heads, f)
with open(f'{RUN_NAME}_num_passes_docstring.json', 'w') as f:
    json.dump(num_passes, f)
with open(f'{RUN_NAME}_pruned_attrs_docstring.json', 'w') as f:
    json.dump(cleaned_attrs, f)
