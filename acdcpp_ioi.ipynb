# %%
import os
import sys
import re

import acdc
import numpy as np
import torch as t
from torch import Tensor
import einops
import itertools

from transformer_lens import HookedTransformer, ActivationCache

import tqdm.notebook as tqdm
import plotly
from rich import print as rprint
from rich.table import Table

from jaxtyping import Float, Bool
from typing import Callable, Tuple, Union, Dict, Optional

device = t.device('cuda') if t.cuda.is_available() else t.device('cpu')
print(f'Device: {device}')
# Out:
# Device: cuda

# %% [markdown]
# # Model Setup

# %%
model = HookedTransformer.from_pretrained(
    'gpt2-small',
    center_writing_weights=False,
    center_unembed=False,
    fold_ln=False,
    device=device,
)
model.set_use_hook_mlp_in(True)
model.set_use_split_qkv_input(True)
model.set_use_attn_result(True)
# Out:
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2-small into HookedTransformer

# %% [markdown]
# # Dataset Setup

# %%
from ioi_dataset import IOIDataset, format_prompt, make_table
N = 20
clean_dataset = IOIDataset(
    prompt_type='mixed',
    N=N,
    tokenizer=model.tokenizer,
    prepend_bos=False,
    seed=1,
    device=device
)
corr_dataset = clean_dataset.gen_flipped_prompts('ABC->XYZ, BAB->XYZ')

make_table(
  colnames = ["IOI prompt", "IOI subj", "IOI indirect obj", "ABC prompt"],
  cols = [
    map(format_prompt, clean_dataset.sentences),
    model.to_string(clean_dataset.s_tokenIDs).split(),
    model.to_string(clean_dataset.io_tokenIDs).split(),
    map(format_prompt, clean_dataset.sentences),
  ],
  title = "Sentences from IOI vs ABC distribution",
)
# Out:
#                                       Sentences from IOI vs ABC distribution
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ IOI prompt                              ┃ IOI subj ┃ IOI indirect obj ┃ ABC prompt                              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ When Victoria and Jane got a snack at   │ Jane     │ Victoria         │ When Victoria and Jane got a snack at   │
# │ the store, Jane decided to give it to   │          │                  │ the store, Jane decided to give it to   │
# │ Victoria                                │          │                  │ Victoria                                │
# │                                         │          │                  │                                         │
# │ When Sullivan and Rose got a necklace   │ Sullivan │ Rose             │ When Sullivan and Rose got a necklace   │
# │ at the garden, Sullivan decided to give │          │                  │ at the garden, Sullivan decided to give │
# │ it to Rose                              │          │                  │ it to Rose                              │
# │                                         │          │                  │                                         │
# │ When Alan and Alex got a drink at the   │ Alex     │ Alan             │ When Alan and Alex got a drink at the   │
# │ store, Alex decided to give it to Alan  │          │                  │ store, Alex decided to give it to Alan  │
# │                                         │          │                  │                                         │
# │ Then, Jessica and Crystal had a long    │ Jessica  │ Crystal          │ Then, Jessica and Crystal had a long    │
# │ argument, and afterwards Jessica said   │          │                  │ argument, and afterwards Jessica said   │
# │ to Crystal                              │          │                  │ to Crystal                              │
# │                                         │          │                  │                                         │
# │ Then, Jonathan and Kevin were working   │ Kevin    │ Jonathan         │ Then, Jonathan and Kevin were working   │
# │ at the school. Kevin decided to give a  │          │                  │ at the school. Kevin decided to give a  │
# │ necklace to Jonathan                    │          │                  │ necklace to Jonathan                    │
# │                                         │          │                  │                                         │
# └─────────────────────────────────────────┴──────────┴──────────────────┴─────────────────────────────────────────┘

# %% [markdown]
# # Metric Setup

# %%
def ave_logit_diff(
    logits: Float[Tensor, 'batch seq d_vocab'],
    ioi_dataset: IOIDataset,
    per_prompt: bool = False
):
    '''
        Return average logit difference between correct and incorrect answers
    '''
    # Get logits for indirect objects
    io_logits = logits[range(logits.size(0)), ioi_dataset.word_idx['end'], ioi_dataset.io_tokenIDs]
    s_logits = logits[range(logits.size(0)), ioi_dataset.word_idx['end'], ioi_dataset.s_tokenIDs]
    # Get logits for subject
    logit_diff = io_logits - s_logits
    return logit_diff if per_prompt else logit_diff.mean()

with t.no_grad():
    clean_logits = model(clean_dataset.toks)
    corrupt_logits = model(corr_dataset.toks)
    clean_logit_diff = ave_logit_diff(clean_logits, clean_dataset).item()
    corrupt_logit_diff = ave_logit_diff(corrupt_logits, corr_dataset).item()

def ioi_metric(
    logits: Float[Tensor, "batch seq_len d_vocab"],
    corrupted_logit_diff: float = corrupt_logit_diff,
    clean_logit_diff: float = clean_logit_diff,
    ioi_dataset: IOIDataset = clean_dataset
 ):
    patched_logit_diff = ave_logit_diff(logits, ioi_dataset)
    return (patched_logit_diff - corrupted_logit_diff) / (clean_logit_diff - corrupted_logit_diff)

# Get clean and corrupt logit differences
with t.no_grad():
    clean_metric = ioi_metric(clean_logits, corrupt_logit_diff, clean_logit_diff, clean_dataset)
    corrupt_metric = ioi_metric(corrupt_logits, corrupt_logit_diff, clean_logit_diff, corr_dataset)

print(f'Clean direction: {clean_logit_diff}, Corrupt direction: {corrupt_logit_diff}')
print(f'Clean metric: {clean_metric}, Corrupt metric: {corrupt_metric}')
# Out:
# Clean direction: 2.6958870887756348, Corrupt direction: 1.5606025457382202
# Clean metric: 1.0, Corrupt metric: 0.0

# %% [markdown]
# # Experiment Setup

# %%
from acdc.TLACDCExperiment import TLACDCExperiment
from acdc.acdc_utils import TorchIndex, EdgeType

# Set up experiment
exp = TLACDCExperiment(
    model=model,
    threshold=0.00001,
    ds=clean_dataset.toks,
    ref_ds=corr_dataset.toks,
    metric=ioi_metric,
    zero_ablation=True,
    hook_verbose=False
)

# Set up computational graph
exp.model.reset_hooks()
exp.setup_model_hooks(
    add_sender_hooks=True,
    add_receiver_hooks=True,
    doing_acdc_runs=False,
)
# Out:
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.11.hook_resid_post
# blocks.11.hook_mlp_out
# blocks.11.mlp.hook_post
# blocks.11.mlp.hook_pre
# blocks.11.ln2.hook_normalized
# blocks.11.ln2.hook_scale
# blocks.11.hook_mlp_in
# blocks.11.hook_resid_mid
# blocks.11.hook_attn_out
# blocks.11.attn.hook_result
# blocks.11.attn.hook_z
# blocks.11.attn.hook_pattern
# blocks.11.attn.hook_attn_scores
# blocks.11.attn.hook_v
# blocks.11.attn.hook_k
# blocks.11.attn.hook_q
# blocks.11.ln1.hook_normalized
# blocks.11.ln1.hook_scale
# blocks.11.hook_v_input
# blocks.11.hook_k_input
# blocks.11.hook_q_input
# blocks.11.hook_resid_pre
# blocks.10.hook_resid_post
# blocks.10.hook_mlp_out
# blocks.10.mlp.hook_post
# blocks.10.mlp.hook_pre
# blocks.10.ln2.hook_normalized
# blocks.10.ln2.hook_scale
# blocks.10.hook_mlp_in
# blocks.10.hook_resid_mid
# blocks.10.hook_attn_out
# blocks.10.attn.hook_result
# blocks.10.attn.hook_z
# blocks.10.attn.hook_pattern
# blocks.10.attn.hook_attn_scores
# blocks.10.attn.hook_v
# blocks.10.attn.hook_k
# blocks.10.attn.hook_q
# blocks.10.ln1.hook_normalized
# blocks.10.ln1.hook_scale
# blocks.10.hook_v_input
# blocks.10.hook_k_input
# blocks.10.hook_q_input
# blocks.10.hook_resid_pre
# blocks.9.hook_resid_post
# blocks.9.hook_mlp_out
# blocks.9.mlp.hook_post
# blocks.9.mlp.hook_pre
# blocks.9.ln2.hook_normalized
# blocks.9.ln2.hook_scale
# blocks.9.hook_mlp_in
# blocks.9.hook_resid_mid
# blocks.9.hook_attn_out
# blocks.9.attn.hook_result
# blocks.9.attn.hook_z
# blocks.9.attn.hook_pattern
# blocks.9.attn.hook_attn_scores
# blocks.9.attn.hook_v
# blocks.9.attn.hook_k
# blocks.9.attn.hook_q
# blocks.9.ln1.hook_normalized
# blocks.9.ln1.hook_scale
# blocks.9.hook_v_input
# blocks.9.hook_k_input
# blocks.9.hook_q_input
# blocks.9.hook_resid_pre
# blocks.8.hook_resid_post
# blocks.8.hook_mlp_out
# blocks.8.mlp.hook_post
# blocks.8.mlp.hook_pre
# blocks.8.ln2.hook_normalized
# blocks.8.ln2.hook_scale
# blocks.8.hook_mlp_in
# blocks.8.hook_resid_mid
# blocks.8.hook_attn_out
# blocks.8.attn.hook_result
# blocks.8.attn.hook_z
# blocks.8.attn.hook_pattern
# blocks.8.attn.hook_attn_scores
# blocks.8.attn.hook_v
# blocks.8.attn.hook_k
# blocks.8.attn.hook_q
# blocks.8.ln1.hook_normalized
# blocks.8.ln1.hook_scale
# blocks.8.hook_v_input
# blocks.8.hook_k_input
# blocks.8.hook_q_input
# blocks.8.hook_resid_pre
# blocks.7.hook_resid_post
# blocks.7.hook_mlp_out
# blocks.7.mlp.hook_post
# blocks.7.mlp.hook_pre
# blocks.7.ln2.hook_normalized
# blocks.7.ln2.hook_scale
# blocks.7.hook_mlp_in
# blocks.7.hook_resid_mid
# blocks.7.hook_attn_out
# blocks.7.attn.hook_result
# blocks.7.attn.hook_z
# blocks.7.attn.hook_pattern
# blocks.7.attn.hook_attn_scores
# blocks.7.attn.hook_v
# blocks.7.attn.hook_k
# blocks.7.attn.hook_q
# blocks.7.ln1.hook_normalized
# blocks.7.ln1.hook_scale
# blocks.7.hook_v_input
# blocks.7.hook_k_input
# blocks.7.hook_q_input
# blocks.7.hook_resid_pre
# blocks.6.hook_resid_post
# blocks.6.hook_mlp_out
# blocks.6.mlp.hook_post
# blocks.6.mlp.hook_pre
# blocks.6.ln2.hook_normalized
# blocks.6.ln2.hook_scale
# blocks.6.hook_mlp_in
# blocks.6.hook_resid_mid
# blocks.6.hook_attn_out
# blocks.6.attn.hook_result
# blocks.6.attn.hook_z
# blocks.6.attn.hook_pattern
# blocks.6.attn.hook_attn_scores
# blocks.6.attn.hook_v
# blocks.6.attn.hook_k
# blocks.6.attn.hook_q
# blocks.6.ln1.hook_normalized
# blocks.6.ln1.hook_scale
# blocks.6.hook_v_input
# blocks.6.hook_k_input
# blocks.6.hook_q_input
# blocks.6.hook_resid_pre
# blocks.5.hook_resid_post
# blocks.5.hook_mlp_out
# blocks.5.mlp.hook_post
# blocks.5.mlp.hook_pre
# blocks.5.ln2.hook_normalized
# blocks.5.ln2.hook_scale
# blocks.5.hook_mlp_in
# blocks.5.hook_resid_mid
# blocks.5.hook_attn_out
# blocks.5.attn.hook_result
# blocks.5.attn.hook_z
# blocks.5.attn.hook_pattern
# blocks.5.attn.hook_attn_scores
# blocks.5.attn.hook_v
# blocks.5.attn.hook_k
# blocks.5.attn.hook_q
# blocks.5.ln1.hook_normalized
# blocks.5.ln1.hook_scale
# blocks.5.hook_v_input
# blocks.5.hook_k_input
# blocks.5.hook_q_input
# blocks.5.hook_resid_pre
# blocks.4.hook_resid_post
# blocks.4.hook_mlp_out
# blocks.4.mlp.hook_post
# blocks.4.mlp.hook_pre
# blocks.4.ln2.hook_normalized
# blocks.4.ln2.hook_scale
# blocks.4.hook_mlp_in
# blocks.4.hook_resid_mid
# blocks.4.hook_attn_out
# blocks.4.attn.hook_result
# blocks.4.attn.hook_z
# blocks.4.attn.hook_pattern
# blocks.4.attn.hook_attn_scores
# blocks.4.attn.hook_v
# blocks.4.attn.hook_k
# blocks.4.attn.hook_q
# blocks.4.ln1.hook_normalized
# blocks.4.ln1.hook_scale
# blocks.4.hook_v_input
# blocks.4.hook_k_input
# blocks.4.hook_q_input
# blocks.4.hook_resid_pre
# blocks.3.hook_resid_post
# blocks.3.hook_mlp_out
# blocks.3.mlp.hook_post
# blocks.3.mlp.hook_pre
# blocks.3.ln2.hook_normalized
# blocks.3.ln2.hook_scale
# blocks.3.hook_mlp_in
# blocks.3.hook_resid_mid
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_mlp_out
# blocks.2.mlp.hook_post
# blocks.2.mlp.hook_pre
# blocks.2.ln2.hook_normalized
# blocks.2.ln2.hook_scale
# blocks.2.hook_mlp_in
# blocks.2.hook_resid_mid
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_mlp_out
# blocks.1.mlp.hook_post
# blocks.1.mlp.hook_pre
# blocks.1.ln2.hook_normalized
# blocks.1.ln2.hook_scale
# blocks.1.hook_mlp_in
# blocks.1.hook_resid_mid
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_mlp_out
# blocks.0.mlp.hook_post
# blocks.0.mlp.hook_pre
# blocks.0.ln2.hook_normalized
# blocks.0.ln2.hook_scale
# blocks.0.hook_mlp_in
# blocks.0.hook_resid_mid
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:])

# %%
exp.corr.edges['blocks.6.attn.hook_result'][TorchIndex([None, None, 6])]
# Out:
# defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#             {'blocks.6.attn.hook_q': defaultdict(None,
#                          {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#              'blocks.6.attn.hook_k': defaultdict(None,
#                          {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#              'blocks.6.attn.hook_v': defaultdict(None,
#                          {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)})})

# %%
exp.corr.edges['blocks.6.hook_k_input'][TorchIndex([None, None, 6])]
# Out:
# defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#             {'blocks.5.hook_mlp_out': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.5.attn.hook_result': defaultdict(None,
#                          {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.4.hook_mlp_out': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.4.attn.hook_result': defaultdict(None,
#                          {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.3.hook_mlp_out': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.3.attn.hook_result': defaultdict(None,
#                          {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.2.hook_mlp_out': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.2.attn.hook_result': defaultdict(None,
#                          {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.1.hook_mlp_out': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.1.attn.hook_result': defaultdict(None,
#                          {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.0.hook_mlp_out': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.0.attn.hook_result': defaultdict(None,
#                          {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                           [:, :, 1]: Edge(EdgeType.ADDITION, True)}),
#              'blocks.0.hook_resid_pre': defaultdict(None,
#                          {[:]: Edge(EdgeType.ADDITION, True)})})

# %%
exp.corr.graph['blocks.6.attn.hook_result'][TorchIndex([None, None, 6])].children
# Out:
# [TLACDCInterpNode(blocks.11.hook_resid_post, [:]),
#  TLACDCInterpNode(blocks.11.hook_mlp_in, [:]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_mlp_in, [:]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_mlp_in, [:]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_mlp_in, [:]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.7.hook_mlp_in, [:]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 11]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 10]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 9]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 8]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 7]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 6]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 5]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 4]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 3]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 2]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 1]),
#  TLACDCInterpNode(blocks.7.hook_q_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.7.hook_k_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.7.hook_v_input, [:, :, 0]),
#  TLACDCInterpNode(blocks.6.hook_mlp_in, [:])]

# %%
for child_hook_name in exp.corr.edges:
    print(child_hook_name)
# Out:
# blocks.11.hook_resid_post
# blocks.11.hook_mlp_out
# blocks.11.hook_mlp_in
# blocks.11.attn.hook_result
# blocks.11.attn.hook_q
# blocks.11.attn.hook_k
# blocks.11.attn.hook_v
# blocks.11.hook_q_input
# blocks.11.hook_k_input
# blocks.11.hook_v_input
# blocks.10.hook_mlp_out
# blocks.10.hook_mlp_in
# blocks.10.attn.hook_result
# blocks.10.attn.hook_q
# blocks.10.attn.hook_k
# blocks.10.attn.hook_v
# blocks.10.hook_q_input
# blocks.10.hook_k_input
# blocks.10.hook_v_input
# blocks.9.hook_mlp_out
# blocks.9.hook_mlp_in
# blocks.9.attn.hook_result
# blocks.9.attn.hook_q
# blocks.9.attn.hook_k
# blocks.9.attn.hook_v
# blocks.9.hook_q_input
# blocks.9.hook_k_input
# blocks.9.hook_v_input
# blocks.8.hook_mlp_out
# blocks.8.hook_mlp_in
# blocks.8.attn.hook_result
# blocks.8.attn.hook_q
# blocks.8.attn.hook_k
# blocks.8.attn.hook_v
# blocks.8.hook_q_input
# blocks.8.hook_k_input
# blocks.8.hook_v_input
# blocks.7.hook_mlp_out
# blocks.7.hook_mlp_in
# blocks.7.attn.hook_result
# blocks.7.attn.hook_q
# blocks.7.attn.hook_k
# blocks.7.attn.hook_v
# blocks.7.hook_q_input
# blocks.7.hook_k_input
# blocks.7.hook_v_input
# blocks.6.hook_mlp_out
# blocks.6.hook_mlp_in
# blocks.6.attn.hook_result
# blocks.6.attn.hook_q
# blocks.6.attn.hook_k
# blocks.6.attn.hook_v
# blocks.6.hook_q_input
# blocks.6.hook_k_input
# blocks.6.hook_v_input
# blocks.5.hook_mlp_out
# blocks.5.hook_mlp_in
# blocks.5.attn.hook_result
# blocks.5.attn.hook_q
# blocks.5.attn.hook_k
# blocks.5.attn.hook_v
# blocks.5.hook_q_input
# blocks.5.hook_k_input
# blocks.5.hook_v_input
# blocks.4.hook_mlp_out
# blocks.4.hook_mlp_in
# blocks.4.attn.hook_result
# blocks.4.attn.hook_q
# blocks.4.attn.hook_k
# blocks.4.attn.hook_v
# blocks.4.hook_q_input
# blocks.4.hook_k_input
# blocks.4.hook_v_input
# blocks.3.hook_mlp_out
# blocks.3.hook_mlp_in
# blocks.3.attn.hook_result
# blocks.3.attn.hook_q
# blocks.3.attn.hook_k
# blocks.3.attn.hook_v
# blocks.3.hook_q_input
# blocks.3.hook_k_input
# blocks.3.hook_v_input
# blocks.2.hook_mlp_out
# blocks.2.hook_mlp_in
# blocks.2.attn.hook_result
# blocks.2.attn.hook_q
# blocks.2.attn.hook_k
# blocks.2.attn.hook_v
# blocks.2.hook_q_input
# blocks.2.hook_k_input
# blocks.2.hook_v_input
# blocks.1.hook_mlp_out
# blocks.1.hook_mlp_in
# blocks.1.attn.hook_result
# blocks.1.attn.hook_q
# blocks.1.attn.hook_k
# blocks.1.attn.hook_v
# blocks.1.hook_q_input
# blocks.1.hook_k_input
# blocks.1.hook_v_input
# blocks.0.hook_mlp_out
# blocks.0.hook_mlp_in
# blocks.0.attn.hook_result
# blocks.0.attn.hook_q
# blocks.0.attn.hook_k
# blocks.0.attn.hook_v
# blocks.0.hook_q_input
# blocks.0.hook_k_input
# blocks.0.hook_v_input
# blocks.6.attn.hook_k_input

# %%
# What nodes point into an attn head?

# What nodes does the attn head point out to?

# Removing both of the above edges should remove the node itself

# %% [markdown]
# # Helper Methods

# %%
def remove_redundant_node(exp, node, safe=True, allow_fails=True):
        if safe:
            for parent_name in exp.corr.edges[node.name][node.index]:
                for parent_index in exp.corr.edges[node.name][node.index][parent_name]:
                    if exp.corr.edges[node.name][node.index][parent_name][parent_index].present:
                        raise Exception(f"You should not be removing a node that is still used by another node {node} {(parent_name, parent_index)}")

        bfs = [node]
        bfs_idx = 0

        while bfs_idx < len(bfs):
            cur_node = bfs[bfs_idx]
            bfs_idx += 1

            children = exp.corr.graph[cur_node.name][cur_node.index].children

            for child_node in children:
                if not cur_node.index in exp.corr.edges[child_node.name][child_node.index][cur_node.name]:
                    continue
                    
                try:
                    print(f'\t Removing edge {child_node.name}, {child_node.index} <-> {cur_node.name}, {cur_node.index}')
                    exp.corr.remove_edge(
                        child_node.name, child_node.index, cur_node.name, cur_node.index
                    )
                except KeyError as e:
                    print("Got an error", e)
                    if allow_fails:
                        continue
                    else:
                        raise e

                remove_this = True
                for parent_of_child_name in exp.corr.edges[child_node.name][child_node.index]:
                    for parent_of_child_index in exp.corr.edges[child_node.name][child_node.index][parent_of_child_name]:
                        if exp.corr.edges[child_node.name][child_node.index][parent_of_child_name][parent_of_child_index].present:
                            remove_this = False
                            break
                    if not remove_this:
                        break

                if remove_this and child_node not in bfs:
                    bfs.append(child_node)

def remove_node(exp, node):
    '''
        Method that removes node from model. Assumes children point towards
        the end of the residual stream and parents point towards the beginning.

        exp: A TLACDCExperiment object with a reverse top sorted graph
        node: A TLACDCInterpNode describing the node to remove
        root: Initally the first node in the graph
    '''
    #Removing all edges pointing to the node
    remove_edges = []
    for p_name in exp.corr.edges[node.name][node.index]:
        for p_idx in exp.corr.edges[node.name][node.index][p_name]:
            edge = exp.corr.edges[node.name][node.index][p_name][p_idx]
            remove_edges.append((node.name, node.index, p_name, p_idx))
            edge.present = False
    for n_name, n_idx, p_name, p_idx in remove_edges:
        print(f'\t Removing edge {p_name}, {p_idx} <-> {n_name}, {n_idx}')
        exp.corr.remove_edge(
            n_name, n_idx, p_name, p_idx
        )
    # Removing all outgoing edges from the node using BFS
    remove_redundant_node(exp, node, safe=False)

def find_attn_node(exp, layer, head):
    return exp.corr.graph[f'blocks.{layer}.attn.hook_result'][TorchIndex([None, None, head])]

def find_attn_node_qkv(exp, layer, head):
    nodes = []
    for qkv in ['q', 'k', 'v']:
        nodes.append(exp.corr.graph[f'blocks.{layer}.attn.hook_{qkv}'][TorchIndex([None, None, head])])
        nodes.append(exp.corr.graph[f'blocks.{layer}.hook_{qkv}_input'][TorchIndex([None, None, head])])
    return nodes
    
def split_layers_and_heads(act: Tensor, model: HookedTransformer) -> Tensor:
    return einops.rearrange(act, '(layer head) batch seq d_model -> layer head batch seq d_model',
                            layer=model.cfg.n_layers,
                            head=model.cfg.n_heads)

hook_filter = lambda name: name.endswith("ln1.hook_normalized") or name.endswith("attn.hook_result")
def get_3_caches(model, clean_input, corrupted_input, metric):
    # cache the activations and gradients of the clean inputs
    model.reset_hooks()
    clean_cache = {}

    def forward_cache_hook(act, hook):
        clean_cache[hook.name] = act.detach()

    model.add_hook(hook_filter, forward_cache_hook, "fwd")

    clean_grad_cache = {}

    def backward_cache_hook(act, hook):
        clean_grad_cache[hook.name] = act.detach()

    model.add_hook(hook_filter, backward_cache_hook, "bwd")

    value = metric(model(clean_input))
    value.backward()

    # cache the activations of the corrupted inputs
    model.reset_hooks()
    corrupted_cache = {}

    def forward_cache_hook(act, hook):
        corrupted_cache[hook.name] = act.detach()

    model.add_hook(hook_filter, forward_cache_hook, "fwd")
    model(corrupted_input)
    model.reset_hooks()

    clean_cache = ActivationCache(clean_cache, model)
    corrupted_cache = ActivationCache(corrupted_cache, model)
    clean_grad_cache = ActivationCache(clean_grad_cache, model)
    return clean_cache, corrupted_cache, clean_grad_cache

def acdc_nodes(model: HookedTransformer,
              clean_input: Tensor,
              corrupted_input: Tensor,
              metric: Callable[[Tensor], Tensor],
              threshold: float,
              exp: TLACDCExperiment,
              attr_absolute_val: bool = False) -> Tuple[
                  HookedTransformer, Bool[Tensor, 'n_layer n_heads']]:
    '''
    Runs attribution-patching-based ACDC on the model, using the given metric and data.
    Returns the pruned model, and which heads were pruned.

    Arguments:
        model: the model to prune
        clean_input: the input to the model that contains should elicit the behavior we're looking for
        corrupted_input: the input to the model that should elicit random behavior
        metric: the metric to use to compare the model's performance on the clean and corrupted inputs
        threshold: the threshold below which to prune
        create_model: a function that returns a new model of the same type as the input model
        attr_absolute_val: whether to take the absolute value of the attribution before thresholding
    '''
    # get the 2 fwd and 1 bwd caches; cache "normalized" and "result" of attn layers
    clean_cache, corrupted_cache, clean_grad_cache = get_3_caches(model, clean_input, corrupted_input, metric)

    # compute first-order Taylor approximation for each node to get the attribution
    clean_head_act = clean_cache.stack_head_results()
    corr_head_act = corrupted_cache.stack_head_results()
    clean_grad_act = clean_grad_cache.stack_head_results()

    # compute attributions of each node
    node_attr = (clean_head_act - corr_head_act) * clean_grad_act
    # separate layers and heads, sum over d_model (to complete the dot product), batch, and seq
    node_attr = split_layers_and_heads(node_attr, model).sum((2, 3, 4))

    if attr_absolute_val:
        node_attr = node_attr.abs()
    del clean_cache
    del clean_head_act
    del corrupted_cache
    del corr_head_act
    del clean_grad_cache
    del clean_grad_act
    t.cuda.empty_cache()
    # prune all nodes whose attribution is below the threshold
    should_prune = node_attr < threshold
    pruned_nodes_attr = {}
    for layer, head in itertools.product(range(model.cfg.n_layers), range(model.cfg.n_heads)):
        if should_prune[layer, head]:
            # REMOVING NODE
            print(f'PRUNING L{layer}H{head} with attribution {node_attr[layer, head]}')
            # Find the corresponding node in computation graph
            node = find_attn_node(exp, layer, head)
            print(f'\tFound node {node.name}')
            # Prune node
            remove_node(exp, node)
            print(f'\tRemoved node {node.name}')
            pruned_nodes_attr[(layer, head)] = node_attr[layer, head]
            
            # REMOVING QKV
            qkv_nodes = find_attn_node_qkv(exp, layer, head)
            for node in qkv_nodes:
                remove_node(exp, node)
    return pruned_nodes_attr

# %% [markdown]
# # Run Experiment

# %%
THRESHOLD = 0.5
pruned_nodes_attr = acdc_nodes(
    model=exp.model,
    clean_input=clean_dataset.toks,
    corrupted_input=corr_dataset.toks,
    metric=ioi_metric,
    threshold=THRESHOLD,
    exp=exp,
    attr_absolute_val=True,
) 
t.cuda.empty_cache()
# Out:
# PRUNING L0H0 with attribution 0.008111419156193733
# 	Found node blocks.0.attn.hook_result
# 	 Removing edge blocks.11.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.9.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.7.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.5.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.3.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 0]
# 	Removed node blocks.0.attn.hook_result
# 	 Removing edge blocks.0.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_q, [:, :, 0]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.0.hook_q_input, [:, :, 0]
# 	 Removing edge blocks.0.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_k, [:, :, 0]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.0.hook_k_input, [:, :, 0]
# 	 Removing edge blocks.0.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_v, [:, :, 0]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.0.hook_v_input, [:, :, 0]
# PRUNING L0H1 with attribution 0.04757048934698105
# 	Found node blocks.0.attn.hook_result
# 	 Removing edge blocks.0.attn.hook_q, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.0.attn.hook_k, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.0.attn.hook_v, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_resid_post, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.8.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.7.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.6.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.5.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.4.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.3.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.2.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.1.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	 Removing edge blocks.0.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 1]
# 	Removed node blocks.0.attn.hook_result
# 	 Removing edge blocks.0.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_q, [:, :, 1]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.0.hook_q_input, [:, :, 1]
# 	 Removing edge blocks.0.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_k, [:, :, 1]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.0.hook_k_input, [:, :, 1]
# 	 Removing edge blocks.0.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_v, [:, :, 1]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.0.hook_v_input, [:, :, 1]
# PRUNING L0H2 with attribution 0.01889432966709137
# 	Found node blocks.0.attn.hook_result
# 	 Removing edge blocks.0.attn.hook_q, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.0.attn.hook_k, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.0.attn.hook_v, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_resid_post, [:] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.10.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.8.hook_mlp_in, [:] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 11] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 10] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 9] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 8] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 7] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 6] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 5] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 4] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 3] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 2] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_k_input, [:, :, 1] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_q_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# 	 Removing edge blocks.9.hook_v_input, [:, :, 0] <-> blocks.0.attn.hook_result, [:, :, 2]
# ...
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 8]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 8]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 8]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 8]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_q_input, [:, :, 8]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 8] <-> blocks.11.attn.hook_k, [:, :, 8]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_k_input, [:, :, 8]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 8] <-> blocks.11.attn.hook_v, [:, :, 8]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 11] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 10] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 9] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 8] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 6] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 5] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 4] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 3] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 2] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 1] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 0] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_v_input, [:, :, 8]
# PRUNING L11H9 with attribution 0.062103331089019775
# 	Found node blocks.11.attn.hook_result
# 	 Removing edge blocks.11.attn.hook_q, [:, :, 9] <-> blocks.11.attn.hook_result, [:, :, 9]
# 	 Removing edge blocks.11.attn.hook_k, [:, :, 9] <-> blocks.11.attn.hook_result, [:, :, 9]
# 	 Removing edge blocks.11.attn.hook_v, [:, :, 9] <-> blocks.11.attn.hook_result, [:, :, 9]
# 	 Removing edge blocks.11.hook_resid_post, [:] <-> blocks.11.attn.hook_result, [:, :, 9]
# 	Removed node blocks.11.attn.hook_result
# 	 Removing edge blocks.11.hook_q_input, [:, :, 9] <-> blocks.11.attn.hook_q, [:, :, 9]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_q_input, [:, :, 9]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 9] <-> blocks.11.attn.hook_k, [:, :, 9]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 11] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 10] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 9] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 8] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 6] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 5] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 4] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 3] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 2] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 1] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 0] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_k_input, [:, :, 9]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 9] <-> blocks.11.attn.hook_v, [:, :, 9]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_v_input, [:, :, 9]
# PRUNING L11H11 with attribution 0.004000210203230381
# 	Found node blocks.11.attn.hook_result
# 	 Removing edge blocks.11.attn.hook_q, [:, :, 11] <-> blocks.11.attn.hook_result, [:, :, 11]
# 	 Removing edge blocks.11.attn.hook_k, [:, :, 11] <-> blocks.11.attn.hook_result, [:, :, 11]
# 	 Removing edge blocks.11.attn.hook_v, [:, :, 11] <-> blocks.11.attn.hook_result, [:, :, 11]
# 	 Removing edge blocks.11.hook_resid_post, [:] <-> blocks.11.attn.hook_result, [:, :, 11]
# 	Removed node blocks.11.attn.hook_result
# 	 Removing edge blocks.11.hook_q_input, [:, :, 11] <-> blocks.11.attn.hook_q, [:, :, 11]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_q_input, [:, :, 11]
# 	 Removing edge blocks.11.hook_k_input, [:, :, 11] <-> blocks.11.attn.hook_k, [:, :, 11]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 11] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 10] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 9] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 8] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 6] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 5] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 4] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 3] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 2] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 1] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 0] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_k_input, [:, :, 11]
# 	 Removing edge blocks.11.hook_v_input, [:, :, 11] <-> blocks.11.attn.hook_v, [:, :, 11]
# 	 Removing edge blocks.10.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.10.attn.hook_result, [:, :, 7] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.9.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.8.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 10] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.8.attn.hook_result, [:, :, 6] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.7.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.7.attn.hook_result, [:, :, 9] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.6.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.5.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.4.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.3.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.2.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.1.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.0.hook_mlp_out, [:] <-> blocks.11.hook_v_input, [:, :, 11]
# 	 Removing edge blocks.0.hook_resid_pre, [:] <-> blocks.11.hook_v_input, [:, :, 11]

# %% [markdown]
# # Show resulting graph

# %%
from acdc.TLACDCInterpNode import TLACDCInterpNode
import pygraphviz as pgv
from pathlib import Path

def get_node_name(node: TLACDCInterpNode, show_full_index=True):
    """Node name for use in pretty graphs"""

    if not show_full_index:
        name = ""
        qkv_substrings = [f"hook_{letter}" for letter in ["q", "k", "v"]]
        qkv_input_substrings = [f"hook_{letter}_input" for letter in ["q", "k", "v"]]

        # Handle embedz
        if "resid_pre" in node.name:
            assert "0" in node.name and not any([str(i) in node.name for i in range(1, 10)])
            name += "embed"
            if len(node.index.hashable_tuple) > 2:
                name += f"_[{node.index.hashable_tuple[2]}]"
            return name

        elif "embed" in node.name:
            name = "pos_embeds" if "pos" in node.name else "token_embeds"

        # Handle q_input and hook_q etc
        elif any([node.name.endswith(qkv_input_substring) for qkv_input_substring in qkv_input_substrings]):
            relevant_letter = None
            for letter, qkv_substring in zip(["q", "k", "v"], qkv_substrings):
                if qkv_substring in node.name:
                    assert relevant_letter is None
                    relevant_letter = letter
            name += "a" + node.name.split(".")[1] + "." + str(node.index.hashable_tuple[2]) + "_" + relevant_letter

        # Handle attention hook_result
        elif "hook_result" in node.name or any([qkv_substring in node.name for qkv_substring in qkv_substrings]):
            name = "a" + node.name.split(".")[1] + "." + str(node.index.hashable_tuple[2])

        # Handle MLPs
        elif node.name.endswith("resid_mid"):
            raise ValueError("We removed resid_mid annotations. Call these mlp_in now.")
        elif node.name.endswith("mlp_out") or node.name.endswith("mlp_in"):
            name = "m" + node.name.split(".")[1]

        # Handle resid_post
        elif "resid_post" in node.name:
            name += "resid_post"

        else:
            raise ValueError(f"Unrecognized node name {node.name}")

    else:
        
        name = node.name + str(node.index.graphviz_index(use_actual_colon=True))

    return "<" + name + ">"

def generate_random_color(colorscheme: str) -> str:
    """
    https://stackoverflow.com/questions/28999287/generate-random-colors-rgb
    """
    def rgb2hex(rgb):
        """
        https://stackoverflow.com/questions/3380726/converting-an-rgb-color-tuple-to-a-hexidecimal-string
        """
        return "#{:02x}{:02x}{:02x}".format(rgb[0], rgb[1], rgb[2])

    return rgb2hex((np.random.randint(0, 256), np.random.randint(0, 256), np.random.randint(0, 256)))

def build_colorscheme(correspondence, colorscheme: str = "Pastel2", show_full_index=True) -> Dict[str, str]:
    colors = {}
    for node in correspondence.nodes():
        colors[get_node_name(node, show_full_index=show_full_index)] = generate_random_color(colorscheme)
    return colors

def show(
    correspondence: TLACDCInterpNode,
    fname=None,
    colorscheme: Union[Dict, str] = "Pastel2",
    minimum_penwidth: float = 0.3,
    show_full_index: bool = False,
    remove_self_loops: bool = True,
    remove_qkv: bool = True,
    layout: str="dot",
    edge_type_colouring: bool = False,
    show_placeholders: bool = False,
    seed: Optional[int] = None
):
    g = pgv.AGraph(directed=True, bgcolor="transparent", overlap="false", splines="true", layout=layout)

    if seed is not None:
        np.random.seed(seed)
    
    groups = {}
    if isinstance(colorscheme, str):
        colors = build_colorscheme(correspondence, colorscheme, show_full_index=show_full_index)
    else:
        colors = colorscheme
        for name, color in colors.items():
            if color not in groups:
                groups[color] = [name]
            else:
                groups[color].append(name)

    node_pos = {}
    if fname is not None:
        base_fname = ".".join(str(fname).split(".")[:-1])

        base_path = Path(base_fname)
        fpath = base_path / "layout.gv"
        if fpath.exists():
            g_pos = pgv.AGraph()
            g_pos.read(fpath)
            for node in g_pos.nodes():
                node_pos[node.name] = node.attr["pos"]
    
    for child_hook_name in correspondence.edges:
        for child_index in correspondence.edges[child_hook_name]:
            for parent_hook_name in correspondence.edges[child_hook_name][child_index]:
                for parent_index in correspondence.edges[child_hook_name][child_index][parent_hook_name]:
                    edge = correspondence.edges[child_hook_name][child_index][parent_hook_name][parent_index]

                    parent = correspondence.graph[parent_hook_name][parent_index]
                    child = correspondence.graph[child_hook_name][child_index]

                    parent_name = get_node_name(parent, show_full_index=show_full_index)
                    child_name = get_node_name(child, show_full_index=show_full_index)
                    
                    if remove_qkv:
                        if any(qkv in child_name or qkv in parent_name for qkv in ['_q_', '_k_', '_v_']):
                            continue
                        parent_name = parent_name.replace("_q>", ">").replace("_k>", ">").replace("_v>", ">")
                        child_name = child_name.replace("_q>", ">").replace("_k>", ">").replace("_v>", ">")

                    if remove_self_loops and parent_name == child_name:
                        # Important this go after the qkv removal
                        continue
                    
                    if edge.present and (edge.edge_type != EdgeType.PLACEHOLDER or show_placeholders):
                        print(f'Edge from {parent_name=} to {child_name=}')
                        for node_name in [parent_name, child_name]:
                            maybe_pos = {}
                            if node_name in node_pos:
                                maybe_pos["pos"] = node_pos[node_name]
                            g.add_node(
                                node_name,
                                fillcolor=colors[node_name],
                                color="black",
                                style="filled, rounded",
                                shape="box",
                                fontname="Helvetica",
                                **maybe_pos,
                            )
                        
                        g.add_edge(
                            parent_name,
                            child_name,
                            penwidth=str(minimum_penwidth * 2),
                            color=colors[parent_name] if not edge_type_colouring else EDGE_TYPE_COLORS[edge.edge_type.value],
                        )
    if fname is not None:
        base_fname = ".".join(str(fname).split(".")[:-1])

        base_path = Path(base_fname)
        base_path.mkdir(exist_ok=True)
        for k, s in groups.items():
            g2 = pgv.AGraph(directed=True, bgcolor="transparent", overlap="false", splines="true", layout="neato")
            for node_name in s:
                g2.add_node(
                    node_name,
                    style="filled, rounded",
                    shape="box",
                )
            for i in range(len(s)):
                for j in range(i + 1, len(s)):
                    g2.add_edge(s[i], s[j], style="invis", weight=200)
            g2.write(path=base_path / f"{k}.gv")

        g.write(path=base_fname + ".gv")

        if not fname.endswith(".gv"): # turn the .gv file into a .png file
            g.draw(path=fname, prog="dot")

    return g
g = show(exp.corr, fname='test.png')
# Out:
# Edge from parent_name='<m11>' to child_name='<resid_post>'
# Edge from parent_name='<a11.10>' to child_name='<resid_post>'
# Edge from parent_name='<m10>' to child_name='<resid_post>'
# Edge from parent_name='<a10.7>' to child_name='<resid_post>'
# Edge from parent_name='<m9>' to child_name='<resid_post>'
# Edge from parent_name='<m8>' to child_name='<resid_post>'
# Edge from parent_name='<a8.10>' to child_name='<resid_post>'
# Edge from parent_name='<a8.6>' to child_name='<resid_post>'
# Edge from parent_name='<m7>' to child_name='<resid_post>'
# Edge from parent_name='<a7.9>' to child_name='<resid_post>'
# Edge from parent_name='<m6>' to child_name='<resid_post>'
# Edge from parent_name='<m5>' to child_name='<resid_post>'
# Edge from parent_name='<m4>' to child_name='<resid_post>'
# Edge from parent_name='<m3>' to child_name='<resid_post>'
# Edge from parent_name='<m2>' to child_name='<resid_post>'
# Edge from parent_name='<m1>' to child_name='<resid_post>'
# Edge from parent_name='<m0>' to child_name='<resid_post>'
# Edge from parent_name='embed' to child_name='<resid_post>'
# Edge from parent_name='<a11.11>' to child_name='<m11>'
# Edge from parent_name='<a11.10>' to child_name='<m11>'
# Edge from parent_name='<a11.9>' to child_name='<m11>'
# Edge from parent_name='<a11.8>' to child_name='<m11>'
# Edge from parent_name='<a11.7>' to child_name='<m11>'
# Edge from parent_name='<a11.6>' to child_name='<m11>'
# Edge from parent_name='<a11.5>' to child_name='<m11>'
# Edge from parent_name='<a11.4>' to child_name='<m11>'
# Edge from parent_name='<a11.3>' to child_name='<m11>'
# Edge from parent_name='<a11.2>' to child_name='<m11>'
# Edge from parent_name='<a11.1>' to child_name='<m11>'
# Edge from parent_name='<a11.0>' to child_name='<m11>'
# Edge from parent_name='<m10>' to child_name='<m11>'
# Edge from parent_name='<a10.11>' to child_name='<m11>'
# Edge from parent_name='<a10.10>' to child_name='<m11>'
# Edge from parent_name='<a10.9>' to child_name='<m11>'
# Edge from parent_name='<a10.8>' to child_name='<m11>'
# Edge from parent_name='<a10.7>' to child_name='<m11>'
# Edge from parent_name='<a10.6>' to child_name='<m11>'
# Edge from parent_name='<a10.5>' to child_name='<m11>'
# Edge from parent_name='<a10.4>' to child_name='<m11>'
# Edge from parent_name='<a10.3>' to child_name='<m11>'
# Edge from parent_name='<a10.2>' to child_name='<m11>'
# Edge from parent_name='<a10.1>' to child_name='<m11>'
# Edge from parent_name='<a10.0>' to child_name='<m11>'
# Edge from parent_name='<m9>' to child_name='<m11>'
# Edge from parent_name='<a9.11>' to child_name='<m11>'
# Edge from parent_name='<a9.10>' to child_name='<m11>'
# Edge from parent_name='<a9.9>' to child_name='<m11>'
# Edge from parent_name='<a9.8>' to child_name='<m11>'
# Edge from parent_name='<a9.7>' to child_name='<m11>'
# Edge from parent_name='<a9.6>' to child_name='<m11>'
# Edge from parent_name='<a9.5>' to child_name='<m11>'
# Edge from parent_name='<a9.4>' to child_name='<m11>'
# Edge from parent_name='<a9.3>' to child_name='<m11>'
# Edge from parent_name='<a9.2>' to child_name='<m11>'
# Edge from parent_name='<a9.1>' to child_name='<m11>'
# Edge from parent_name='<a9.0>' to child_name='<m11>'
# Edge from parent_name='<m8>' to child_name='<m11>'
# Edge from parent_name='<a8.11>' to child_name='<m11>'
# Edge from parent_name='<a8.10>' to child_name='<m11>'
# Edge from parent_name='<a8.9>' to child_name='<m11>'
# Edge from parent_name='<a8.8>' to child_name='<m11>'
# Edge from parent_name='<a8.7>' to child_name='<m11>'
# Edge from parent_name='<a8.6>' to child_name='<m11>'
# Edge from parent_name='<a8.5>' to child_name='<m11>'
# Edge from parent_name='<a8.4>' to child_name='<m11>'
# Edge from parent_name='<a8.3>' to child_name='<m11>'
# Edge from parent_name='<a8.2>' to child_name='<m11>'
# Edge from parent_name='<a8.1>' to child_name='<m11>'
# Edge from parent_name='<a8.0>' to child_name='<m11>'
# Edge from parent_name='<m7>' to child_name='<m11>'
# Edge from parent_name='<a7.11>' to child_name='<m11>'
# Edge from parent_name='<a7.10>' to child_name='<m11>'
# Edge from parent_name='<a7.9>' to child_name='<m11>'
# Edge from parent_name='<a7.8>' to child_name='<m11>'
# Edge from parent_name='<a7.7>' to child_name='<m11>'
# Edge from parent_name='<a7.6>' to child_name='<m11>'
# Edge from parent_name='<a7.5>' to child_name='<m11>'
# Edge from parent_name='<a7.4>' to child_name='<m11>'
# Edge from parent_name='<a7.3>' to child_name='<m11>'
# Edge from parent_name='<a7.2>' to child_name='<m11>'
# Edge from parent_name='<a7.1>' to child_name='<m11>'
# Edge from parent_name='<a7.0>' to child_name='<m11>'
# Edge from parent_name='<m6>' to child_name='<m11>'
# Edge from parent_name='<a6.11>' to child_name='<m11>'
# Edge from parent_name='<a6.10>' to child_name='<m11>'
# Edge from parent_name='<a6.9>' to child_name='<m11>'
# Edge from parent_name='<a6.8>' to child_name='<m11>'
# Edge from parent_name='<a6.7>' to child_name='<m11>'
# Edge from parent_name='<a6.6>' to child_name='<m11>'
# Edge from parent_name='<a6.5>' to child_name='<m11>'
# Edge from parent_name='<a6.4>' to child_name='<m11>'
# Edge from parent_name='<a6.3>' to child_name='<m11>'
# Edge from parent_name='<a6.2>' to child_name='<m11>'
# Edge from parent_name='<a6.1>' to child_name='<m11>'
# Edge from parent_name='<a6.0>' to child_name='<m11>'
# Edge from parent_name='<m5>' to child_name='<m11>'
# Edge from parent_name='<a5.11>' to child_name='<m11>'
# Edge from parent_name='<a5.10>' to child_name='<m11>'
# Edge from parent_name='<a5.9>' to child_name='<m11>'
# Edge from parent_name='<a5.8>' to child_name='<m11>'
# Edge from parent_name='<a5.7>' to child_name='<m11>'
# Edge from parent_name='<a5.6>' to child_name='<m11>'
# Edge from parent_name='<a5.5>' to child_name='<m11>'
# Edge from parent_name='<a5.4>' to child_name='<m11>'
# Edge from parent_name='<a5.3>' to child_name='<m11>'
# Edge from parent_name='<a5.2>' to child_name='<m11>'
# Edge from parent_name='<a5.1>' to child_name='<m11>'
# Edge from parent_name='<a5.0>' to child_name='<m11>'
# Edge from parent_name='<m4>' to child_name='<m11>'
# Edge from parent_name='<a4.11>' to child_name='<m11>'
# Edge from parent_name='<a4.10>' to child_name='<m11>'
# Edge from parent_name='<a4.9>' to child_name='<m11>'
# Edge from parent_name='<a4.8>' to child_name='<m11>'
# Edge from parent_name='<a4.7>' to child_name='<m11>'
# Edge from parent_name='<a4.6>' to child_name='<m11>'
# Edge from parent_name='<a4.5>' to child_name='<m11>'
# Edge from parent_name='<a4.4>' to child_name='<m11>'
# Edge from parent_name='<a4.3>' to child_name='<m11>'
# Edge from parent_name='<a4.2>' to child_name='<m11>'
# Edge from parent_name='<a4.1>' to child_name='<m11>'
# Edge from parent_name='<a4.0>' to child_name='<m11>'
# Edge from parent_name='<m3>' to child_name='<m11>'
# Edge from parent_name='<a3.11>' to child_name='<m11>'
# Edge from parent_name='<a3.10>' to child_name='<m11>'
# Edge from parent_name='<a3.9>' to child_name='<m11>'
# Edge from parent_name='<a3.8>' to child_name='<m11>'
# Edge from parent_name='<a3.7>' to child_name='<m11>'
# Edge from parent_name='<a3.6>' to child_name='<m11>'
# Edge from parent_name='<a3.5>' to child_name='<m11>'
# Edge from parent_name='<a3.4>' to child_name='<m11>'
# Edge from parent_name='<a3.3>' to child_name='<m11>'
# Edge from parent_name='<a3.2>' to child_name='<m11>'
# Edge from parent_name='<a3.1>' to child_name='<m11>'
# Edge from parent_name='<a3.0>' to child_name='<m11>'
# Edge from parent_name='<m2>' to child_name='<m11>'
# Edge from parent_name='<a2.11>' to child_name='<m11>'
# Edge from parent_name='<a2.10>' to child_name='<m11>'
# Edge from parent_name='<a2.9>' to child_name='<m11>'
# Edge from parent_name='<a2.8>' to child_name='<m11>'
# Edge from parent_name='<a2.7>' to child_name='<m11>'
# Edge from parent_name='<a2.6>' to child_name='<m11>'
# Edge from parent_name='<a2.5>' to child_name='<m11>'
# Edge from parent_name='<a2.4>' to child_name='<m11>'
# Edge from parent_name='<a2.3>' to child_name='<m11>'
# Edge from parent_name='<a2.2>' to child_name='<m11>'
# Edge from parent_name='<a2.1>' to child_name='<m11>'
# Edge from parent_name='<a2.0>' to child_name='<m11>'
# Edge from parent_name='<m1>' to child_name='<m11>'
# Edge from parent_name='<a1.11>' to child_name='<m11>'
# Edge from parent_name='<a1.10>' to child_name='<m11>'
# Edge from parent_name='<a1.9>' to child_name='<m11>'
# Edge from parent_name='<a1.8>' to child_name='<m11>'
# Edge from parent_name='<a1.7>' to child_name='<m11>'
# Edge from parent_name='<a1.6>' to child_name='<m11>'
# Edge from parent_name='<a1.5>' to child_name='<m11>'
# Edge from parent_name='<a1.4>' to child_name='<m11>'
# Edge from parent_name='<a1.3>' to child_name='<m11>'
# Edge from parent_name='<a1.2>' to child_name='<m11>'
# Edge from parent_name='<a1.1>' to child_name='<m11>'
# Edge from parent_name='<a1.0>' to child_name='<m11>'
# Edge from parent_name='<m0>' to child_name='<m11>'
# Edge from parent_name='<a0.11>' to child_name='<m11>'
# Edge from parent_name='<a0.10>' to child_name='<m11>'
# Edge from parent_name='<a0.9>' to child_name='<m11>'
# Edge from parent_name='<a0.8>' to child_name='<m11>'
# Edge from parent_name='<a0.7>' to child_name='<m11>'
# Edge from parent_name='<a0.6>' to child_name='<m11>'
# Edge from parent_name='<a0.5>' to child_name='<m11>'
# Edge from parent_name='<a0.4>' to child_name='<m11>'
# Edge from parent_name='<a0.3>' to child_name='<m11>'
# Edge from parent_name='<a0.2>' to child_name='<m11>'
# Edge from parent_name='<a0.1>' to child_name='<m11>'
# Edge from parent_name='embed' to child_name='<m11>'
# Edge from parent_name='<m10>' to child_name='<a11.10>'
# Edge from parent_name='<a10.11>' to child_name='<a11.10>'
# Edge from parent_name='<a10.10>' to child_name='<a11.10>'
# Edge from parent_name='<a10.9>' to child_name='<a11.10>'
# Edge from parent_name='<a10.8>' to child_name='<a11.10>'
# Edge from parent_name='<a10.7>' to child_name='<a11.10>'
# Edge from parent_name='<a10.6>' to child_name='<a11.10>'
# Edge from parent_name='<a10.5>' to child_name='<a11.10>'
# Edge from parent_name='<a10.4>' to child_name='<a11.10>'
# Edge from parent_name='<a10.3>' to child_name='<a11.10>'
# Edge from parent_name='<a10.2>' to child_name='<a11.10>'
# Edge from parent_name='<a10.1>' to child_name='<a11.10>'
# Edge from parent_name='<a10.0>' to child_name='<a11.10>'
# Edge from parent_name='<m9>' to child_name='<a11.10>'
# Edge from parent_name='<m8>' to child_name='<a11.10>'
# Edge from parent_name='<a8.10>' to child_name='<a11.10>'
# Edge from parent_name='<a8.6>' to child_name='<a11.10>'
# Edge from parent_name='<m7>' to child_name='<a11.10>'
# Edge from parent_name='<a7.9>' to child_name='<a11.10>'
# Edge from parent_name='<m6>' to child_name='<a11.10>'
# Edge from parent_name='<m5>' to child_name='<a11.10>'
# Edge from parent_name='<m4>' to child_name='<a11.10>'
# Edge from parent_name='<m3>' to child_name='<a11.10>'
# Edge from parent_name='<m2>' to child_name='<a11.10>'
# Edge from parent_name='<m1>' to child_name='<a11.10>'
# Edge from parent_name='<m0>' to child_name='<a11.10>'
# Edge from parent_name='embed' to child_name='<a11.10>'
# Edge from parent_name='<m10>' to child_name='<a11.10>'
# Edge from parent_name='<a10.7>' to child_name='<a11.10>'
# Edge from parent_name='<m9>' to child_name='<a11.10>'
# Edge from parent_name='<m8>' to child_name='<a11.10>'
# Edge from parent_name='<a8.10>' to child_name='<a11.10>'
# Edge from parent_name='<a8.6>' to child_name='<a11.10>'
# Edge from parent_name='<m7>' to child_name='<a11.10>'
# Edge from parent_name='<a7.9>' to child_name='<a11.10>'
# Edge from parent_name='<m6>' to child_name='<a11.10>'
# Edge from parent_name='<m5>' to child_name='<a11.10>'
# Edge from parent_name='<m4>' to child_name='<a11.10>'
# Edge from parent_name='<m3>' to child_name='<a11.10>'
# Edge from parent_name='<m2>' to child_name='<a11.10>'
# Edge from parent_name='<m1>' to child_name='<a11.10>'
# Edge from parent_name='<m0>' to child_name='<a11.10>'
# Edge from parent_name='embed' to child_name='<a11.10>'
# Edge from parent_name='<m10>' to child_name='<a11.10>'
# Edge from parent_name='<a10.11>' to child_name='<a11.10>'
# Edge from parent_name='<a10.10>' to child_name='<a11.10>'
# Edge from parent_name='<a10.9>' to child_name='<a11.10>'
# Edge from parent_name='<a10.8>' to child_name='<a11.10>'
# Edge from parent_name='<a10.7>' to child_name='<a11.10>'
# Edge from parent_name='<a10.6>' to child_name='<a11.10>'
# Edge from parent_name='<a10.5>' to child_name='<a11.10>'
# Edge from parent_name='<a10.4>' to child_name='<a11.10>'
# Edge from parent_name='<a10.3>' to child_name='<a11.10>'
# Edge from parent_name='<a10.2>' to child_name='<a11.10>'
# Edge from parent_name='<a10.1>' to child_name='<a11.10>'
# Edge from parent_name='<a10.0>' to child_name='<a11.10>'
# Edge from parent_name='<m9>' to child_name='<a11.10>'
# Edge from parent_name='<m8>' to child_name='<a11.10>'
# Edge from parent_name='<a8.10>' to child_name='<a11.10>'
# Edge from parent_name='<a8.6>' to child_name='<a11.10>'
# Edge from parent_name='<m7>' to child_name='<a11.10>'
# Edge from parent_name='<a7.9>' to child_name='<a11.10>'
# Edge from parent_name='<m6>' to child_name='<a11.10>'
# Edge from parent_name='<m5>' to child_name='<a11.10>'
# Edge from parent_name='<m4>' to child_name='<a11.10>'
# Edge from parent_name='<m3>' to child_name='<a11.10>'
# Edge from parent_name='<m2>' to child_name='<a11.10>'
# Edge from parent_name='<m1>' to child_name='<a11.10>'
# Edge from parent_name='<m0>' to child_name='<a11.10>'
# Edge from parent_name='embed' to child_name='<a11.10>'
# Edge from parent_name='<a10.7>' to child_name='<m10>'
# Edge from parent_name='<m9>' to child_name='<m10>'
# Edge from parent_name='<m8>' to child_name='<m10>'
# Edge from parent_name='<a8.10>' to child_name='<m10>'
# Edge from parent_name='<a8.6>' to child_name='<m10>'
# Edge from parent_name='<m7>' to child_name='<m10>'
# Edge from parent_name='<a7.9>' to child_name='<m10>'
# Edge from parent_name='<m6>' to child_name='<m10>'
# Edge from parent_name='<m5>' to child_name='<m10>'
# Edge from parent_name='<m4>' to child_name='<m10>'
# Edge from parent_name='<m3>' to child_name='<m10>'
# Edge from parent_name='<m2>' to child_name='<m10>'
# Edge from parent_name='<m1>' to child_name='<m10>'
# Edge from parent_name='<m0>' to child_name='<m10>'
# Edge from parent_name='embed' to child_name='<m10>'
# Edge from parent_name='<m9>' to child_name='<a10.7>'
# Edge from parent_name='<a9.11>' to child_name='<a10.7>'
# Edge from parent_name='<a9.10>' to child_name='<a10.7>'
# Edge from parent_name='<a9.9>' to child_name='<a10.7>'
# Edge from parent_name='<a9.8>' to child_name='<a10.7>'
# Edge from parent_name='<a9.7>' to child_name='<a10.7>'
# Edge from parent_name='<a9.6>' to child_name='<a10.7>'
# Edge from parent_name='<a9.5>' to child_name='<a10.7>'
# Edge from parent_name='<a9.4>' to child_name='<a10.7>'
# Edge from parent_name='<a9.3>' to child_name='<a10.7>'
# Edge from parent_name='<a9.2>' to child_name='<a10.7>'
# Edge from parent_name='<a9.1>' to child_name='<a10.7>'
# Edge from parent_name='<a9.0>' to child_name='<a10.7>'
# Edge from parent_name='<m8>' to child_name='<a10.7>'
# Edge from parent_name='<a8.10>' to child_name='<a10.7>'
# Edge from parent_name='<a8.6>' to child_name='<a10.7>'
# Edge from parent_name='<m7>' to child_name='<a10.7>'
# Edge from parent_name='<a7.9>' to child_name='<a10.7>'
# Edge from parent_name='<m6>' to child_name='<a10.7>'
# Edge from parent_name='<m5>' to child_name='<a10.7>'
# Edge from parent_name='<m4>' to child_name='<a10.7>'
# Edge from parent_name='<m3>' to child_name='<a10.7>'
# Edge from parent_name='<m2>' to child_name='<a10.7>'
# Edge from parent_name='<m1>' to child_name='<a10.7>'
# Edge from parent_name='<m0>' to child_name='<a10.7>'
# Edge from parent_name='embed' to child_name='<a10.7>'
# Edge from parent_name='<m9>' to child_name='<a10.7>'
# Edge from parent_name='<m8>' to child_name='<a10.7>'
# Edge from parent_name='<a8.10>' to child_name='<a10.7>'
# Edge from parent_name='<a8.6>' to child_name='<a10.7>'
# Edge from parent_name='<m7>' to child_name='<a10.7>'
# Edge from parent_name='<a7.9>' to child_name='<a10.7>'
# Edge from parent_name='<m6>' to child_name='<a10.7>'
# Edge from parent_name='<m5>' to child_name='<a10.7>'
# Edge from parent_name='<m4>' to child_name='<a10.7>'
# Edge from parent_name='<m3>' to child_name='<a10.7>'
# Edge from parent_name='<m2>' to child_name='<a10.7>'
# Edge from parent_name='<m1>' to child_name='<a10.7>'
# Edge from parent_name='<m0>' to child_name='<a10.7>'
# Edge from parent_name='embed' to child_name='<a10.7>'
# Edge from parent_name='<m9>' to child_name='<a10.7>'
# Edge from parent_name='<a9.11>' to child_name='<a10.7>'
# Edge from parent_name='<a9.10>' to child_name='<a10.7>'
# Edge from parent_name='<a9.9>' to child_name='<a10.7>'
# Edge from parent_name='<a9.8>' to child_name='<a10.7>'
# Edge from parent_name='<a9.7>' to child_name='<a10.7>'
# Edge from parent_name='<a9.6>' to child_name='<a10.7>'
# Edge from parent_name='<a9.5>' to child_name='<a10.7>'
# Edge from parent_name='<a9.4>' to child_name='<a10.7>'
# Edge from parent_name='<a9.3>' to child_name='<a10.7>'
# Edge from parent_name='<a9.2>' to child_name='<a10.7>'
# Edge from parent_name='<a9.1>' to child_name='<a10.7>'
# Edge from parent_name='<a9.0>' to child_name='<a10.7>'
# Edge from parent_name='<m8>' to child_name='<a10.7>'
# Edge from parent_name='<a8.10>' to child_name='<a10.7>'
# Edge from parent_name='<a8.6>' to child_name='<a10.7>'
# Edge from parent_name='<m7>' to child_name='<a10.7>'
# Edge from parent_name='<a7.9>' to child_name='<a10.7>'
# Edge from parent_name='<m6>' to child_name='<a10.7>'
# Edge from parent_name='<m5>' to child_name='<a10.7>'
# Edge from parent_name='<m4>' to child_name='<a10.7>'
# Edge from parent_name='<m3>' to child_name='<a10.7>'
# Edge from parent_name='<m2>' to child_name='<a10.7>'
# Edge from parent_name='<m1>' to child_name='<a10.7>'
# Edge from parent_name='<m0>' to child_name='<a10.7>'
# Edge from parent_name='embed' to child_name='<a10.7>'
# Edge from parent_name='<a9.11>' to child_name='<m9>'
# Edge from parent_name='<a9.10>' to child_name='<m9>'
# Edge from parent_name='<a9.9>' to child_name='<m9>'
# Edge from parent_name='<a9.8>' to child_name='<m9>'
# Edge from parent_name='<a9.7>' to child_name='<m9>'
# Edge from parent_name='<a9.6>' to child_name='<m9>'
# Edge from parent_name='<a9.5>' to child_name='<m9>'
# Edge from parent_name='<a9.4>' to child_name='<m9>'
# Edge from parent_name='<a9.3>' to child_name='<m9>'
# Edge from parent_name='<a9.2>' to child_name='<m9>'
# Edge from parent_name='<a9.1>' to child_name='<m9>'
# Edge from parent_name='<a9.0>' to child_name='<m9>'
# Edge from parent_name='<m8>' to child_name='<m9>'
# Edge from parent_name='<a8.11>' to child_name='<m9>'
# Edge from parent_name='<a8.10>' to child_name='<m9>'
# Edge from parent_name='<a8.9>' to child_name='<m9>'
# Edge from parent_name='<a8.8>' to child_name='<m9>'
# Edge from parent_name='<a8.7>' to child_name='<m9>'
# Edge from parent_name='<a8.6>' to child_name='<m9>'
# Edge from parent_name='<a8.5>' to child_name='<m9>'
# Edge from parent_name='<a8.4>' to child_name='<m9>'
# Edge from parent_name='<a8.3>' to child_name='<m9>'
# Edge from parent_name='<a8.2>' to child_name='<m9>'
# Edge from parent_name='<a8.1>' to child_name='<m9>'
# Edge from parent_name='<a8.0>' to child_name='<m9>'
# Edge from parent_name='<m7>' to child_name='<m9>'
# Edge from parent_name='<a7.11>' to child_name='<m9>'
# Edge from parent_name='<a7.10>' to child_name='<m9>'
# Edge from parent_name='<a7.9>' to child_name='<m9>'
# Edge from parent_name='<a7.8>' to child_name='<m9>'
# Edge from parent_name='<a7.7>' to child_name='<m9>'
# Edge from parent_name='<a7.6>' to child_name='<m9>'
# Edge from parent_name='<a7.5>' to child_name='<m9>'
# Edge from parent_name='<a7.4>' to child_name='<m9>'
# Edge from parent_name='<a7.3>' to child_name='<m9>'
# Edge from parent_name='<a7.2>' to child_name='<m9>'
# Edge from parent_name='<a7.1>' to child_name='<m9>'
# Edge from parent_name='<a7.0>' to child_name='<m9>'
# Edge from parent_name='<m6>' to child_name='<m9>'
# Edge from parent_name='<a6.11>' to child_name='<m9>'
# Edge from parent_name='<a6.10>' to child_name='<m9>'
# Edge from parent_name='<a6.9>' to child_name='<m9>'
# Edge from parent_name='<a6.8>' to child_name='<m9>'
# Edge from parent_name='<a6.7>' to child_name='<m9>'
# Edge from parent_name='<a6.6>' to child_name='<m9>'
# Edge from parent_name='<a6.5>' to child_name='<m9>'
# Edge from parent_name='<a6.4>' to child_name='<m9>'
# Edge from parent_name='<a6.3>' to child_name='<m9>'
# Edge from parent_name='<a6.2>' to child_name='<m9>'
# Edge from parent_name='<a6.1>' to child_name='<m9>'
# Edge from parent_name='<a6.0>' to child_name='<m9>'
# Edge from parent_name='<m5>' to child_name='<m9>'
# Edge from parent_name='<a5.11>' to child_name='<m9>'
# Edge from parent_name='<a5.10>' to child_name='<m9>'
# Edge from parent_name='<a5.9>' to child_name='<m9>'
# Edge from parent_name='<a5.8>' to child_name='<m9>'
# Edge from parent_name='<a5.7>' to child_name='<m9>'
# Edge from parent_name='<a5.6>' to child_name='<m9>'
# Edge from parent_name='<a5.5>' to child_name='<m9>'
# Edge from parent_name='<a5.4>' to child_name='<m9>'
# Edge from parent_name='<a5.3>' to child_name='<m9>'
# Edge from parent_name='<a5.2>' to child_name='<m9>'
# Edge from parent_name='<a5.1>' to child_name='<m9>'
# Edge from parent_name='<a5.0>' to child_name='<m9>'
# Edge from parent_name='<m4>' to child_name='<m9>'
# Edge from parent_name='<a4.11>' to child_name='<m9>'
# Edge from parent_name='<a4.10>' to child_name='<m9>'
# Edge from parent_name='<a4.9>' to child_name='<m9>'
# Edge from parent_name='<a4.8>' to child_name='<m9>'
# Edge from parent_name='<a4.7>' to child_name='<m9>'
# Edge from parent_name='<a4.6>' to child_name='<m9>'
# Edge from parent_name='<a4.5>' to child_name='<m9>'
# Edge from parent_name='<a4.4>' to child_name='<m9>'
# Edge from parent_name='<a4.3>' to child_name='<m9>'
# Edge from parent_name='<a4.2>' to child_name='<m9>'
# Edge from parent_name='<a4.1>' to child_name='<m9>'
# Edge from parent_name='<a4.0>' to child_name='<m9>'
# Edge from parent_name='<m3>' to child_name='<m9>'
# Edge from parent_name='<a3.11>' to child_name='<m9>'
# Edge from parent_name='<a3.10>' to child_name='<m9>'
# Edge from parent_name='<a3.9>' to child_name='<m9>'
# Edge from parent_name='<a3.8>' to child_name='<m9>'
# Edge from parent_name='<a3.7>' to child_name='<m9>'
# Edge from parent_name='<a3.6>' to child_name='<m9>'
# Edge from parent_name='<a3.5>' to child_name='<m9>'
# Edge from parent_name='<a3.4>' to child_name='<m9>'
# Edge from parent_name='<a3.3>' to child_name='<m9>'
# Edge from parent_name='<a3.2>' to child_name='<m9>'
# Edge from parent_name='<a3.1>' to child_name='<m9>'
# Edge from parent_name='<a3.0>' to child_name='<m9>'
# Edge from parent_name='<m2>' to child_name='<m9>'
# Edge from parent_name='<a2.11>' to child_name='<m9>'
# Edge from parent_name='<a2.10>' to child_name='<m9>'
# Edge from parent_name='<a2.9>' to child_name='<m9>'
# Edge from parent_name='<a2.8>' to child_name='<m9>'
# Edge from parent_name='<a2.7>' to child_name='<m9>'
# Edge from parent_name='<a2.6>' to child_name='<m9>'
# Edge from parent_name='<a2.5>' to child_name='<m9>'
# Edge from parent_name='<a2.4>' to child_name='<m9>'
# Edge from parent_name='<a2.3>' to child_name='<m9>'
# Edge from parent_name='<a2.2>' to child_name='<m9>'
# Edge from parent_name='<a2.1>' to child_name='<m9>'
# Edge from parent_name='<a2.0>' to child_name='<m9>'
# Edge from parent_name='<m1>' to child_name='<m9>'
# Edge from parent_name='<a1.11>' to child_name='<m9>'
# Edge from parent_name='<a1.10>' to child_name='<m9>'
# Edge from parent_name='<a1.9>' to child_name='<m9>'
# Edge from parent_name='<a1.8>' to child_name='<m9>'
# Edge from parent_name='<a1.7>' to child_name='<m9>'
# Edge from parent_name='<a1.6>' to child_name='<m9>'
# Edge from parent_name='<a1.5>' to child_name='<m9>'
# Edge from parent_name='<a1.4>' to child_name='<m9>'
# Edge from parent_name='<a1.3>' to child_name='<m9>'
# Edge from parent_name='<a1.2>' to child_name='<m9>'
# Edge from parent_name='<a1.1>' to child_name='<m9>'
# Edge from parent_name='<a1.0>' to child_name='<m9>'
# Edge from parent_name='<m0>' to child_name='<m9>'
# Edge from parent_name='<a0.11>' to child_name='<m9>'
# Edge from parent_name='<a0.10>' to child_name='<m9>'
# Edge from parent_name='<a0.9>' to child_name='<m9>'
# Edge from parent_name='<a0.8>' to child_name='<m9>'
# Edge from parent_name='<a0.7>' to child_name='<m9>'
# Edge from parent_name='<a0.6>' to child_name='<m9>'
# Edge from parent_name='<a0.5>' to child_name='<m9>'
# Edge from parent_name='<a0.4>' to child_name='<m9>'
# Edge from parent_name='<a0.3>' to child_name='<m9>'
# Edge from parent_name='<a0.2>' to child_name='<m9>'
# Edge from parent_name='<a0.1>' to child_name='<m9>'
# Edge from parent_name='embed' to child_name='<m9>'
# Edge from parent_name='<a8.10>' to child_name='<m8>'
# Edge from parent_name='<a8.6>' to child_name='<m8>'
# Edge from parent_name='<m7>' to child_name='<m8>'
# Edge from parent_name='<a7.9>' to child_name='<m8>'
# Edge from parent_name='<m6>' to child_name='<m8>'
# Edge from parent_name='<m5>' to child_name='<m8>'
# Edge from parent_name='<m4>' to child_name='<m8>'
# Edge from parent_name='<m3>' to child_name='<m8>'
# Edge from parent_name='<m2>' to child_name='<m8>'
# Edge from parent_name='<m1>' to child_name='<m8>'
# Edge from parent_name='<m0>' to child_name='<m8>'
# Edge from parent_name='embed' to child_name='<m8>'
# Edge from parent_name='<m7>' to child_name='<a8.10>'
# Edge from parent_name='<a7.9>' to child_name='<a8.10>'
# Edge from parent_name='<m6>' to child_name='<a8.10>'
# Edge from parent_name='<m5>' to child_name='<a8.10>'
# Edge from parent_name='<m4>' to child_name='<a8.10>'
# Edge from parent_name='<m3>' to child_name='<a8.10>'
# Edge from parent_name='<m2>' to child_name='<a8.10>'
# Edge from parent_name='<m1>' to child_name='<a8.10>'
# Edge from parent_name='<m0>' to child_name='<a8.10>'
# Edge from parent_name='embed' to child_name='<a8.10>'
# Edge from parent_name='<m7>' to child_name='<a8.6>'
# Edge from parent_name='<a7.9>' to child_name='<a8.6>'
# Edge from parent_name='<m6>' to child_name='<a8.6>'
# Edge from parent_name='<m5>' to child_name='<a8.6>'
# Edge from parent_name='<m4>' to child_name='<a8.6>'
# Edge from parent_name='<m3>' to child_name='<a8.6>'
# Edge from parent_name='<m2>' to child_name='<a8.6>'
# Edge from parent_name='<m1>' to child_name='<a8.6>'
# Edge from parent_name='<m0>' to child_name='<a8.6>'
# Edge from parent_name='embed' to child_name='<a8.6>'
# Edge from parent_name='<m7>' to child_name='<a8.10>'
# Edge from parent_name='<a7.11>' to child_name='<a8.10>'
# Edge from parent_name='<a7.10>' to child_name='<a8.10>'
# Edge from parent_name='<a7.9>' to child_name='<a8.10>'
# Edge from parent_name='<a7.8>' to child_name='<a8.10>'
# Edge from parent_name='<a7.7>' to child_name='<a8.10>'
# Edge from parent_name='<a7.6>' to child_name='<a8.10>'
# Edge from parent_name='<a7.5>' to child_name='<a8.10>'
# Edge from parent_name='<a7.4>' to child_name='<a8.10>'
# Edge from parent_name='<a7.3>' to child_name='<a8.10>'
# Edge from parent_name='<a7.2>' to child_name='<a8.10>'
# Edge from parent_name='<a7.1>' to child_name='<a8.10>'
# Edge from parent_name='<a7.0>' to child_name='<a8.10>'
# Edge from parent_name='<m6>' to child_name='<a8.10>'
# Edge from parent_name='<m5>' to child_name='<a8.10>'
# Edge from parent_name='<m4>' to child_name='<a8.10>'
# Edge from parent_name='<m3>' to child_name='<a8.10>'
# Edge from parent_name='<m2>' to child_name='<a8.10>'
# Edge from parent_name='<m1>' to child_name='<a8.10>'
# Edge from parent_name='<m0>' to child_name='<a8.10>'
# Edge from parent_name='embed' to child_name='<a8.10>'
# Edge from parent_name='<m7>' to child_name='<a8.6>'
# Edge from parent_name='<a7.11>' to child_name='<a8.6>'
# Edge from parent_name='<a7.10>' to child_name='<a8.6>'
# Edge from parent_name='<a7.9>' to child_name='<a8.6>'
# Edge from parent_name='<a7.8>' to child_name='<a8.6>'
# Edge from parent_name='<a7.7>' to child_name='<a8.6>'
# Edge from parent_name='<a7.6>' to child_name='<a8.6>'
# Edge from parent_name='<a7.5>' to child_name='<a8.6>'
# Edge from parent_name='<a7.4>' to child_name='<a8.6>'
# Edge from parent_name='<a7.3>' to child_name='<a8.6>'
# Edge from parent_name='<a7.2>' to child_name='<a8.6>'
# Edge from parent_name='<a7.1>' to child_name='<a8.6>'
# Edge from parent_name='<a7.0>' to child_name='<a8.6>'
# Edge from parent_name='<m6>' to child_name='<a8.6>'
# Edge from parent_name='<m5>' to child_name='<a8.6>'
# Edge from parent_name='<m4>' to child_name='<a8.6>'
# Edge from parent_name='<m3>' to child_name='<a8.6>'
# Edge from parent_name='<m2>' to child_name='<a8.6>'
# Edge from parent_name='<m1>' to child_name='<a8.6>'
# Edge from parent_name='<m0>' to child_name='<a8.6>'
# Edge from parent_name='embed' to child_name='<a8.6>'
# Edge from parent_name='<m7>' to child_name='<a8.10>'
# Edge from parent_name='<a7.9>' to child_name='<a8.10>'
# Edge from parent_name='<m6>' to child_name='<a8.10>'
# Edge from parent_name='<m5>' to child_name='<a8.10>'
# Edge from parent_name='<m4>' to child_name='<a8.10>'
# Edge from parent_name='<m3>' to child_name='<a8.10>'
# Edge from parent_name='<m2>' to child_name='<a8.10>'
# Edge from parent_name='<m1>' to child_name='<a8.10>'
# Edge from parent_name='<m0>' to child_name='<a8.10>'
# Edge from parent_name='embed' to child_name='<a8.10>'
# Edge from parent_name='<m7>' to child_name='<a8.6>'
# Edge from parent_name='<a7.9>' to child_name='<a8.6>'
# Edge from parent_name='<m6>' to child_name='<a8.6>'
# Edge from parent_name='<m5>' to child_name='<a8.6>'
# Edge from parent_name='<m4>' to child_name='<a8.6>'
# Edge from parent_name='<m3>' to child_name='<a8.6>'
# Edge from parent_name='<m2>' to child_name='<a8.6>'
# Edge from parent_name='<m1>' to child_name='<a8.6>'
# Edge from parent_name='<m0>' to child_name='<a8.6>'
# Edge from parent_name='embed' to child_name='<a8.6>'
# Edge from parent_name='<a7.11>' to child_name='<m7>'
# Edge from parent_name='<a7.10>' to child_name='<m7>'
# Edge from parent_name='<a7.9>' to child_name='<m7>'
# Edge from parent_name='<a7.8>' to child_name='<m7>'
# Edge from parent_name='<a7.7>' to child_name='<m7>'
# Edge from parent_name='<a7.6>' to child_name='<m7>'
# Edge from parent_name='<a7.5>' to child_name='<m7>'
# Edge from parent_name='<a7.4>' to child_name='<m7>'
# Edge from parent_name='<a7.3>' to child_name='<m7>'
# Edge from parent_name='<a7.2>' to child_name='<m7>'
# Edge from parent_name='<a7.1>' to child_name='<m7>'
# Edge from parent_name='<a7.0>' to child_name='<m7>'
# Edge from parent_name='<m6>' to child_name='<m7>'
# Edge from parent_name='<a6.11>' to child_name='<m7>'
# Edge from parent_name='<a6.10>' to child_name='<m7>'
# Edge from parent_name='<a6.9>' to child_name='<m7>'
# Edge from parent_name='<a6.8>' to child_name='<m7>'
# Edge from parent_name='<a6.7>' to child_name='<m7>'
# Edge from parent_name='<a6.6>' to child_name='<m7>'
# Edge from parent_name='<a6.5>' to child_name='<m7>'
# Edge from parent_name='<a6.4>' to child_name='<m7>'
# Edge from parent_name='<a6.3>' to child_name='<m7>'
# Edge from parent_name='<a6.2>' to child_name='<m7>'
# Edge from parent_name='<a6.1>' to child_name='<m7>'
# Edge from parent_name='<a6.0>' to child_name='<m7>'
# Edge from parent_name='<m5>' to child_name='<m7>'
# Edge from parent_name='<a5.11>' to child_name='<m7>'
# Edge from parent_name='<a5.10>' to child_name='<m7>'
# Edge from parent_name='<a5.9>' to child_name='<m7>'
# Edge from parent_name='<a5.8>' to child_name='<m7>'
# Edge from parent_name='<a5.7>' to child_name='<m7>'
# Edge from parent_name='<a5.6>' to child_name='<m7>'
# Edge from parent_name='<a5.5>' to child_name='<m7>'
# Edge from parent_name='<a5.4>' to child_name='<m7>'
# Edge from parent_name='<a5.3>' to child_name='<m7>'
# Edge from parent_name='<a5.2>' to child_name='<m7>'
# Edge from parent_name='<a5.1>' to child_name='<m7>'
# Edge from parent_name='<a5.0>' to child_name='<m7>'
# Edge from parent_name='<m4>' to child_name='<m7>'
# Edge from parent_name='<a4.11>' to child_name='<m7>'
# Edge from parent_name='<a4.10>' to child_name='<m7>'
# Edge from parent_name='<a4.9>' to child_name='<m7>'
# Edge from parent_name='<a4.8>' to child_name='<m7>'
# Edge from parent_name='<a4.7>' to child_name='<m7>'
# Edge from parent_name='<a4.6>' to child_name='<m7>'
# Edge from parent_name='<a4.5>' to child_name='<m7>'
# Edge from parent_name='<a4.4>' to child_name='<m7>'
# Edge from parent_name='<a4.3>' to child_name='<m7>'
# Edge from parent_name='<a4.2>' to child_name='<m7>'
# Edge from parent_name='<a4.1>' to child_name='<m7>'
# Edge from parent_name='<a4.0>' to child_name='<m7>'
# Edge from parent_name='<m3>' to child_name='<m7>'
# Edge from parent_name='<a3.11>' to child_name='<m7>'
# Edge from parent_name='<a3.10>' to child_name='<m7>'
# Edge from parent_name='<a3.9>' to child_name='<m7>'
# Edge from parent_name='<a3.8>' to child_name='<m7>'
# Edge from parent_name='<a3.7>' to child_name='<m7>'
# Edge from parent_name='<a3.6>' to child_name='<m7>'
# Edge from parent_name='<a3.5>' to child_name='<m7>'
# Edge from parent_name='<a3.4>' to child_name='<m7>'
# Edge from parent_name='<a3.3>' to child_name='<m7>'
# Edge from parent_name='<a3.2>' to child_name='<m7>'
# Edge from parent_name='<a3.1>' to child_name='<m7>'
# Edge from parent_name='<a3.0>' to child_name='<m7>'
# Edge from parent_name='<m2>' to child_name='<m7>'
# Edge from parent_name='<a2.11>' to child_name='<m7>'
# Edge from parent_name='<a2.10>' to child_name='<m7>'
# Edge from parent_name='<a2.9>' to child_name='<m7>'
# Edge from parent_name='<a2.8>' to child_name='<m7>'
# Edge from parent_name='<a2.7>' to child_name='<m7>'
# Edge from parent_name='<a2.6>' to child_name='<m7>'
# Edge from parent_name='<a2.5>' to child_name='<m7>'
# Edge from parent_name='<a2.4>' to child_name='<m7>'
# Edge from parent_name='<a2.3>' to child_name='<m7>'
# Edge from parent_name='<a2.2>' to child_name='<m7>'
# Edge from parent_name='<a2.1>' to child_name='<m7>'
# Edge from parent_name='<a2.0>' to child_name='<m7>'
# Edge from parent_name='<m1>' to child_name='<m7>'
# Edge from parent_name='<a1.11>' to child_name='<m7>'
# Edge from parent_name='<a1.10>' to child_name='<m7>'
# Edge from parent_name='<a1.9>' to child_name='<m7>'
# Edge from parent_name='<a1.8>' to child_name='<m7>'
# Edge from parent_name='<a1.7>' to child_name='<m7>'
# Edge from parent_name='<a1.6>' to child_name='<m7>'
# Edge from parent_name='<a1.5>' to child_name='<m7>'
# Edge from parent_name='<a1.4>' to child_name='<m7>'
# Edge from parent_name='<a1.3>' to child_name='<m7>'
# Edge from parent_name='<a1.2>' to child_name='<m7>'
# Edge from parent_name='<a1.1>' to child_name='<m7>'
# Edge from parent_name='<a1.0>' to child_name='<m7>'
# Edge from parent_name='<m0>' to child_name='<m7>'
# Edge from parent_name='<a0.11>' to child_name='<m7>'
# Edge from parent_name='<a0.10>' to child_name='<m7>'
# Edge from parent_name='<a0.9>' to child_name='<m7>'
# Edge from parent_name='<a0.8>' to child_name='<m7>'
# Edge from parent_name='<a0.7>' to child_name='<m7>'
# Edge from parent_name='<a0.6>' to child_name='<m7>'
# Edge from parent_name='<a0.5>' to child_name='<m7>'
# Edge from parent_name='<a0.4>' to child_name='<m7>'
# Edge from parent_name='<a0.3>' to child_name='<m7>'
# Edge from parent_name='<a0.2>' to child_name='<m7>'
# Edge from parent_name='<a0.1>' to child_name='<m7>'
# Edge from parent_name='embed' to child_name='<m7>'
# Edge from parent_name='<m6>' to child_name='<a7.9>'
# Edge from parent_name='<m5>' to child_name='<a7.9>'
# Edge from parent_name='<m4>' to child_name='<a7.9>'
# Edge from parent_name='<m3>' to child_name='<a7.9>'
# Edge from parent_name='<m2>' to child_name='<a7.9>'
# Edge from parent_name='<m1>' to child_name='<a7.9>'
# Edge from parent_name='<m0>' to child_name='<a7.9>'
# Edge from parent_name='embed' to child_name='<a7.9>'
# Edge from parent_name='<m6>' to child_name='<a7.9>'
# Edge from parent_name='<a6.11>' to child_name='<a7.9>'
# Edge from parent_name='<a6.10>' to child_name='<a7.9>'
# Edge from parent_name='<a6.9>' to child_name='<a7.9>'
# Edge from parent_name='<a6.8>' to child_name='<a7.9>'
# Edge from parent_name='<a6.7>' to child_name='<a7.9>'
# Edge from parent_name='<a6.6>' to child_name='<a7.9>'
# Edge from parent_name='<a6.5>' to child_name='<a7.9>'
# Edge from parent_name='<a6.4>' to child_name='<a7.9>'
# Edge from parent_name='<a6.3>' to child_name='<a7.9>'
# Edge from parent_name='<a6.2>' to child_name='<a7.9>'
# Edge from parent_name='<a6.1>' to child_name='<a7.9>'
# Edge from parent_name='<a6.0>' to child_name='<a7.9>'
# Edge from parent_name='<m5>' to child_name='<a7.9>'
# Edge from parent_name='<m4>' to child_name='<a7.9>'
# Edge from parent_name='<m3>' to child_name='<a7.9>'
# Edge from parent_name='<m2>' to child_name='<a7.9>'
# Edge from parent_name='<m1>' to child_name='<a7.9>'
# Edge from parent_name='<m0>' to child_name='<a7.9>'
# Edge from parent_name='embed' to child_name='<a7.9>'
# Edge from parent_name='<m6>' to child_name='<a7.9>'
# Edge from parent_name='<m5>' to child_name='<a7.9>'
# Edge from parent_name='<m4>' to child_name='<a7.9>'
# Edge from parent_name='<m3>' to child_name='<a7.9>'
# Edge from parent_name='<m2>' to child_name='<a7.9>'
# Edge from parent_name='<m1>' to child_name='<a7.9>'
# Edge from parent_name='<m0>' to child_name='<a7.9>'
# Edge from parent_name='embed' to child_name='<a7.9>'
# Edge from parent_name='<m5>' to child_name='<m6>'
# Edge from parent_name='<m4>' to child_name='<m6>'
# Edge from parent_name='<m3>' to child_name='<m6>'
# Edge from parent_name='<m2>' to child_name='<m6>'
# Edge from parent_name='<m1>' to child_name='<m6>'
# Edge from parent_name='<m0>' to child_name='<m6>'
# Edge from parent_name='embed' to child_name='<m6>'
# Edge from parent_name='<a5.11>' to child_name='<m5>'
# Edge from parent_name='<a5.10>' to child_name='<m5>'
# Edge from parent_name='<a5.9>' to child_name='<m5>'
# Edge from parent_name='<a5.8>' to child_name='<m5>'
# Edge from parent_name='<a5.7>' to child_name='<m5>'
# Edge from parent_name='<a5.6>' to child_name='<m5>'
# Edge from parent_name='<a5.5>' to child_name='<m5>'
# Edge from parent_name='<a5.4>' to child_name='<m5>'
# Edge from parent_name='<a5.3>' to child_name='<m5>'
# Edge from parent_name='<a5.2>' to child_name='<m5>'
# Edge from parent_name='<a5.1>' to child_name='<m5>'
# Edge from parent_name='<a5.0>' to child_name='<m5>'
# Edge from parent_name='<m4>' to child_name='<m5>'
# Edge from parent_name='<a4.11>' to child_name='<m5>'
# Edge from parent_name='<a4.10>' to child_name='<m5>'
# Edge from parent_name='<a4.9>' to child_name='<m5>'
# Edge from parent_name='<a4.8>' to child_name='<m5>'
# Edge from parent_name='<a4.7>' to child_name='<m5>'
# Edge from parent_name='<a4.6>' to child_name='<m5>'
# Edge from parent_name='<a4.5>' to child_name='<m5>'
# Edge from parent_name='<a4.4>' to child_name='<m5>'
# Edge from parent_name='<a4.3>' to child_name='<m5>'
# Edge from parent_name='<a4.2>' to child_name='<m5>'
# Edge from parent_name='<a4.1>' to child_name='<m5>'
# Edge from parent_name='<a4.0>' to child_name='<m5>'
# Edge from parent_name='<m3>' to child_name='<m5>'
# Edge from parent_name='<a3.11>' to child_name='<m5>'
# Edge from parent_name='<a3.10>' to child_name='<m5>'
# Edge from parent_name='<a3.9>' to child_name='<m5>'
# Edge from parent_name='<a3.8>' to child_name='<m5>'
# Edge from parent_name='<a3.7>' to child_name='<m5>'
# Edge from parent_name='<a3.6>' to child_name='<m5>'
# Edge from parent_name='<a3.5>' to child_name='<m5>'
# Edge from parent_name='<a3.4>' to child_name='<m5>'
# Edge from parent_name='<a3.3>' to child_name='<m5>'
# Edge from parent_name='<a3.2>' to child_name='<m5>'
# Edge from parent_name='<a3.1>' to child_name='<m5>'
# Edge from parent_name='<a3.0>' to child_name='<m5>'
# Edge from parent_name='<m2>' to child_name='<m5>'
# Edge from parent_name='<a2.11>' to child_name='<m5>'
# Edge from parent_name='<a2.10>' to child_name='<m5>'
# Edge from parent_name='<a2.9>' to child_name='<m5>'
# Edge from parent_name='<a2.8>' to child_name='<m5>'
# Edge from parent_name='<a2.7>' to child_name='<m5>'
# Edge from parent_name='<a2.6>' to child_name='<m5>'
# Edge from parent_name='<a2.5>' to child_name='<m5>'
# Edge from parent_name='<a2.4>' to child_name='<m5>'
# Edge from parent_name='<a2.3>' to child_name='<m5>'
# Edge from parent_name='<a2.2>' to child_name='<m5>'
# Edge from parent_name='<a2.1>' to child_name='<m5>'
# Edge from parent_name='<a2.0>' to child_name='<m5>'
# Edge from parent_name='<m1>' to child_name='<m5>'
# Edge from parent_name='<a1.11>' to child_name='<m5>'
# Edge from parent_name='<a1.10>' to child_name='<m5>'
# Edge from parent_name='<a1.9>' to child_name='<m5>'
# Edge from parent_name='<a1.8>' to child_name='<m5>'
# Edge from parent_name='<a1.7>' to child_name='<m5>'
# Edge from parent_name='<a1.6>' to child_name='<m5>'
# Edge from parent_name='<a1.5>' to child_name='<m5>'
# Edge from parent_name='<a1.4>' to child_name='<m5>'
# Edge from parent_name='<a1.3>' to child_name='<m5>'
# Edge from parent_name='<a1.2>' to child_name='<m5>'
# Edge from parent_name='<a1.1>' to child_name='<m5>'
# Edge from parent_name='<a1.0>' to child_name='<m5>'
# Edge from parent_name='<m0>' to child_name='<m5>'
# Edge from parent_name='<a0.11>' to child_name='<m5>'
# Edge from parent_name='<a0.10>' to child_name='<m5>'
# Edge from parent_name='<a0.9>' to child_name='<m5>'
# Edge from parent_name='<a0.8>' to child_name='<m5>'
# Edge from parent_name='<a0.7>' to child_name='<m5>'
# Edge from parent_name='<a0.6>' to child_name='<m5>'
# Edge from parent_name='<a0.5>' to child_name='<m5>'
# Edge from parent_name='<a0.4>' to child_name='<m5>'
# Edge from parent_name='<a0.3>' to child_name='<m5>'
# Edge from parent_name='<a0.2>' to child_name='<m5>'
# Edge from parent_name='<a0.1>' to child_name='<m5>'
# Edge from parent_name='embed' to child_name='<m5>'
# Edge from parent_name='<m3>' to child_name='<m4>'
# Edge from parent_name='<m2>' to child_name='<m4>'
# Edge from parent_name='<m1>' to child_name='<m4>'
# Edge from parent_name='<m0>' to child_name='<m4>'
# Edge from parent_name='embed' to child_name='<m4>'
# Edge from parent_name='<a3.11>' to child_name='<m3>'
# Edge from parent_name='<a3.10>' to child_name='<m3>'
# Edge from parent_name='<a3.9>' to child_name='<m3>'
# Edge from parent_name='<a3.8>' to child_name='<m3>'
# Edge from parent_name='<a3.7>' to child_name='<m3>'
# Edge from parent_name='<a3.6>' to child_name='<m3>'
# Edge from parent_name='<a3.5>' to child_name='<m3>'
# Edge from parent_name='<a3.4>' to child_name='<m3>'
# Edge from parent_name='<a3.3>' to child_name='<m3>'
# Edge from parent_name='<a3.2>' to child_name='<m3>'
# Edge from parent_name='<a3.1>' to child_name='<m3>'
# Edge from parent_name='<a3.0>' to child_name='<m3>'
# Edge from parent_name='<m2>' to child_name='<m3>'
# Edge from parent_name='<a2.11>' to child_name='<m3>'
# Edge from parent_name='<a2.10>' to child_name='<m3>'
# Edge from parent_name='<a2.9>' to child_name='<m3>'
# Edge from parent_name='<a2.8>' to child_name='<m3>'
# Edge from parent_name='<a2.7>' to child_name='<m3>'
# Edge from parent_name='<a2.6>' to child_name='<m3>'
# Edge from parent_name='<a2.5>' to child_name='<m3>'
# Edge from parent_name='<a2.4>' to child_name='<m3>'
# Edge from parent_name='<a2.3>' to child_name='<m3>'
# Edge from parent_name='<a2.2>' to child_name='<m3>'
# Edge from parent_name='<a2.1>' to child_name='<m3>'
# Edge from parent_name='<a2.0>' to child_name='<m3>'
# Edge from parent_name='<m1>' to child_name='<m3>'
# Edge from parent_name='<a1.11>' to child_name='<m3>'
# Edge from parent_name='<a1.10>' to child_name='<m3>'
# Edge from parent_name='<a1.9>' to child_name='<m3>'
# Edge from parent_name='<a1.8>' to child_name='<m3>'
# Edge from parent_name='<a1.7>' to child_name='<m3>'
# Edge from parent_name='<a1.6>' to child_name='<m3>'
# Edge from parent_name='<a1.5>' to child_name='<m3>'
# Edge from parent_name='<a1.4>' to child_name='<m3>'
# Edge from parent_name='<a1.3>' to child_name='<m3>'
# Edge from parent_name='<a1.2>' to child_name='<m3>'
# Edge from parent_name='<a1.1>' to child_name='<m3>'
# Edge from parent_name='<a1.0>' to child_name='<m3>'
# Edge from parent_name='<m0>' to child_name='<m3>'
# Edge from parent_name='<a0.11>' to child_name='<m3>'
# Edge from parent_name='<a0.10>' to child_name='<m3>'
# Edge from parent_name='<a0.9>' to child_name='<m3>'
# Edge from parent_name='<a0.8>' to child_name='<m3>'
# Edge from parent_name='<a0.7>' to child_name='<m3>'
# Edge from parent_name='<a0.6>' to child_name='<m3>'
# Edge from parent_name='<a0.5>' to child_name='<m3>'
# Edge from parent_name='<a0.4>' to child_name='<m3>'
# Edge from parent_name='<a0.3>' to child_name='<m3>'
# Edge from parent_name='<a0.2>' to child_name='<m3>'
# Edge from parent_name='<a0.1>' to child_name='<m3>'
# Edge from parent_name='embed' to child_name='<m3>'
# Edge from parent_name='<m1>' to child_name='<m2>'
# Edge from parent_name='<m0>' to child_name='<m2>'
# Edge from parent_name='embed' to child_name='<m2>'
# Edge from parent_name='<a1.11>' to child_name='<m1>'
# Edge from parent_name='<a1.10>' to child_name='<m1>'
# Edge from parent_name='<a1.9>' to child_name='<m1>'
# Edge from parent_name='<a1.8>' to child_name='<m1>'
# Edge from parent_name='<a1.7>' to child_name='<m1>'
# Edge from parent_name='<a1.6>' to child_name='<m1>'
# Edge from parent_name='<a1.5>' to child_name='<m1>'
# Edge from parent_name='<a1.4>' to child_name='<m1>'
# Edge from parent_name='<a1.3>' to child_name='<m1>'
# Edge from parent_name='<a1.2>' to child_name='<m1>'
# Edge from parent_name='<a1.1>' to child_name='<m1>'
# Edge from parent_name='<a1.0>' to child_name='<m1>'
# Edge from parent_name='<m0>' to child_name='<m1>'
# Edge from parent_name='<a0.11>' to child_name='<m1>'
# Edge from parent_name='<a0.10>' to child_name='<m1>'
# Edge from parent_name='<a0.9>' to child_name='<m1>'
# Edge from parent_name='<a0.8>' to child_name='<m1>'
# Edge from parent_name='<a0.7>' to child_name='<m1>'
# Edge from parent_name='<a0.6>' to child_name='<m1>'
# Edge from parent_name='<a0.5>' to child_name='<m1>'
# Edge from parent_name='<a0.4>' to child_name='<m1>'
# Edge from parent_name='<a0.3>' to child_name='<m1>'
# Edge from parent_name='<a0.2>' to child_name='<m1>'
# Edge from parent_name='<a0.1>' to child_name='<m1>'
# Edge from parent_name='embed' to child_name='<m1>'
# Edge from parent_name='embed' to child_name='<m0>'

# %%
g.draw(path='test.png', prog="dot")

# %%
cur_node = find_attn_node(exp, 11, 7)

# %%
cur_node
# Out:
# TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 7])

# %%
children = exp.corr.graph[cur_node.name][cur_node.index].children

for child_node in children:
    print(child_node)
    print(exp.corr.edges[child_node.name][child_node.index][cur_node.name])
# Out:
# blocks.11.hook_mlp_in[:]
# defaultdict(None, {[:, :, 11]: Edge(EdgeType.ADDITION, True), [:, :, 10]: Edge(EdgeType.ADDITION, True), [:, :, 9]: Edge(EdgeType.ADDITION, True), [:, :, 8]: Edge(EdgeType.ADDITION, True), [:, :, 7]: Edge(EdgeType.ADDITION, True), [:, :, 6]: Edge(EdgeType.ADDITION, True), [:, :, 5]: Edge(EdgeType.ADDITION, True), [:, :, 4]: Edge(EdgeType.ADDITION, True), [:, :, 3]: Edge(EdgeType.ADDITION, True), [:, :, 2]: Edge(EdgeType.ADDITION, True), [:, :, 1]: Edge(EdgeType.ADDITION, True), [:, :, 0]: Edge(EdgeType.ADDITION, True)})

# %%
exp.corr.graph
# Out:
# OrderedDict([('blocks.11.hook_resid_post',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.11.hook_resid_post, [:]))])),
#              ('blocks.11.hook_mlp_out',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.11.hook_mlp_out, [:]))])),
#              ('blocks.11.hook_mlp_in',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.11.hook_mlp_in, [:]))])),
#              ('blocks.11.attn.hook_result',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 0]))])),
#              ('blocks.11.attn.hook_v',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.attn.hook_v, [:, :, 0]))])),
#              ('blocks.11.attn.hook_k',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.attn.hook_k, [:, :, 0]))])),
#              ('blocks.11.attn.hook_q',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.attn.hook_q, [:, :, 0]))])),
#              ('blocks.11.hook_v_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.hook_v_input, [:, :, 0]))])),
#              ('blocks.11.hook_k_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.hook_k_input, [:, :, 0]))])),
#              ('blocks.11.hook_q_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.11.hook_q_input, [:, :, 0]))])),
#              ('blocks.10.hook_mlp_out',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.10.hook_mlp_out, [:]))])),
#              ('blocks.10.hook_mlp_in',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.10.hook_mlp_in, [:]))])),
#              ('blocks.10.attn.hook_result',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.attn.hook_result, [:, :, 0]))])),
#              ('blocks.10.attn.hook_v',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.attn.hook_v, [:, :, 0]))])),
#              ('blocks.10.attn.hook_k',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.attn.hook_k, [:, :, 0]))])),
#              ('blocks.10.attn.hook_q',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.attn.hook_q, [:, :, 0]))])),
#              ('blocks.10.hook_v_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.hook_v_input, [:, :, 0]))])),
#              ('blocks.10.hook_k_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.hook_k_input, [:, :, 0]))])),
#              ('blocks.10.hook_q_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.10.hook_q_input, [:, :, 0]))])),
#              ('blocks.9.hook_mlp_out',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.9.hook_mlp_out, [:]))])),
#              ('blocks.9.hook_mlp_in',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.9.hook_mlp_in, [:]))])),
#              ('blocks.9.attn.hook_result',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.attn.hook_result, [:, :, 0]))])),
#              ('blocks.9.attn.hook_v',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.attn.hook_v, [:, :, 0]))])),
#              ('blocks.9.attn.hook_k',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.attn.hook_k, [:, :, 0]))])),
#              ('blocks.9.attn.hook_q',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.attn.hook_q, [:, :, 0]))])),
#              ('blocks.9.hook_v_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.hook_v_input, [:, :, 0]))])),
#              ('blocks.9.hook_k_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.hook_k_input, [:, :, 0]))])),
#              ('blocks.9.hook_q_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.9.hook_q_input, [:, :, 0]))])),
#              ('blocks.8.hook_mlp_out',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.8.hook_mlp_out, [:]))])),
#              ('blocks.8.hook_mlp_in',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.8.hook_mlp_in, [:]))])),
#              ('blocks.8.attn.hook_result',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.attn.hook_result, [:, :, 0]))])),
#              ('blocks.8.attn.hook_v',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.attn.hook_v, [:, :, 0]))])),
#              ('blocks.8.attn.hook_k',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.attn.hook_k, [:, :, 0]))])),
#              ('blocks.8.attn.hook_q',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.attn.hook_q, [:, :, 0]))])),
#              ('blocks.8.hook_v_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.hook_v_input, [:, :, 0]))])),
#              ('blocks.8.hook_k_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.hook_k_input, [:, :, 0]))])),
#              ('blocks.8.hook_q_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.8.hook_q_input, [:, :, 0]))])),
#              ('blocks.7.hook_mlp_out',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.7.hook_mlp_out, [:]))])),
#              ('blocks.7.hook_mlp_in',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.7.hook_mlp_in, [:]))])),
#              ('blocks.7.attn.hook_result',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.7.attn.hook_result, [:, :, 0]))])),
#              ('blocks.7.attn.hook_v',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.7.attn.hook_v, [:, :, 0]))])),
#              ('blocks.7.attn.hook_k',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.7.attn.hook_k, [:, :, 0]))])),
# ...
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.1.attn.hook_q, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.1.attn.hook_q, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.1.attn.hook_q, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.1.attn.hook_q, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.1.attn.hook_q, [:, :, 0]))])),
#              ('blocks.1.hook_v_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.1.hook_v_input, [:, :, 0]))])),
#              ('blocks.1.hook_k_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.1.hook_k_input, [:, :, 0]))])),
#              ('blocks.1.hook_q_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.1.hook_q_input, [:, :, 0]))])),
#              ('blocks.0.hook_mlp_out',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.0.hook_mlp_out, [:]))])),
#              ('blocks.0.hook_mlp_in',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.0.hook_mlp_in, [:]))])),
#              ('blocks.0.attn.hook_result',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 0]))])),
#              ('blocks.0.attn.hook_v',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.attn.hook_v, [:, :, 0]))])),
#              ('blocks.0.attn.hook_k',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.attn.hook_k, [:, :, 0]))])),
#              ('blocks.0.attn.hook_q',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.attn.hook_q, [:, :, 0]))])),
#              ('blocks.0.hook_v_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.hook_v_input, [:, :, 0]))])),
#              ('blocks.0.hook_k_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.hook_k_input, [:, :, 0]))])),
#              ('blocks.0.hook_q_input',
#               OrderedDict([([:, :, 11],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 11])),
#                            ([:, :, 10],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 10])),
#                            ([:, :, 9],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 9])),
#                            ([:, :, 8],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 8])),
#                            ([:, :, 7],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 7])),
#                            ([:, :, 6],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 6])),
#                            ([:, :, 5],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 5])),
#                            ([:, :, 4],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 4])),
#                            ([:, :, 3],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 3])),
#                            ([:, :, 2],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 2])),
#                            ([:, :, 1],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 1])),
#                            ([:, :, 0],
#                             TLACDCInterpNode(blocks.0.hook_q_input, [:, :, 0]))])),
#              ('blocks.0.hook_resid_pre',
#               OrderedDict([([:],
#                             TLACDCInterpNode(blocks.0.hook_resid_pre, [:]))]))])

# %%
pruned_nodes_attr
# Out:
# {(0, 0): tensor(0.0190, device='cuda:0'),
#  (0, 1): tensor(0.1069, device='cuda:0'),
#  (0, 2): tensor(0.0094, device='cuda:0'),
#  (0, 3): tensor(0.0403, device='cuda:0'),
#  (0, 4): tensor(0.0312, device='cuda:0'),
#  (0, 5): tensor(0.0056, device='cuda:0'),
#  (0, 6): tensor(0.0945, device='cuda:0'),
#  (0, 7): tensor(0.0259, device='cuda:0'),
#  (0, 8): tensor(0.0046, device='cuda:0'),
#  (0, 9): tensor(0.0065, device='cuda:0'),
#  (0, 10): tensor(0.0627, device='cuda:0'),
#  (0, 11): tensor(0.0051, device='cuda:0'),
#  (1, 0): tensor(0.0220, device='cuda:0'),
#  (1, 1): tensor(0.0031, device='cuda:0'),
#  (1, 2): tensor(0.0057, device='cuda:0'),
#  (1, 3): tensor(0.0008, device='cuda:0'),
#  (1, 4): tensor(0.0027, device='cuda:0'),
#  (1, 5): tensor(0.0343, device='cuda:0'),
#  (1, 6): tensor(0.0391, device='cuda:0'),
#  (1, 7): tensor(0.0613, device='cuda:0'),
#  (1, 8): tensor(0.0134, device='cuda:0'),
#  (1, 9): tensor(0.0064, device='cuda:0'),
#  (1, 10): tensor(0.0055, device='cuda:0'),
#  (1, 11): tensor(0.0330, device='cuda:0'),
#  (2, 0): tensor(0.0055, device='cuda:0'),
#  (2, 1): tensor(0.0601, device='cuda:0'),
#  (2, 2): tensor(0.0107, device='cuda:0'),
#  (2, 3): tensor(0.0125, device='cuda:0'),
#  (2, 4): tensor(0.0117, device='cuda:0'),
#  (2, 5): tensor(0.0030, device='cuda:0'),
#  (2, 6): tensor(0.0060, device='cuda:0'),
#  (2, 7): tensor(0.0214, device='cuda:0'),
#  (2, 8): tensor(0.0016, device='cuda:0'),
#  (2, 9): tensor(0.0102, device='cuda:0'),
#  (2, 10): tensor(0.0054, device='cuda:0'),
#  (2, 11): tensor(0.0094, device='cuda:0'),
#  (3, 0): tensor(0.2052, device='cuda:0'),
#  (3, 1): tensor(0.0138, device='cuda:0'),
#  (3, 2): tensor(0.0028, device='cuda:0'),
#  (3, 3): tensor(0.0490, device='cuda:0'),
#  (3, 4): tensor(0.0553, device='cuda:0'),
#  (3, 5): tensor(0.0078, device='cuda:0'),
#  (3, 6): tensor(0.0324, device='cuda:0'),
#  (3, 7): tensor(0.0004, device='cuda:0'),
#  (3, 8): tensor(0.0081, device='cuda:0'),
#  (3, 9): tensor(0.0055, device='cuda:0'),
#  (3, 10): tensor(0.0270, device='cuda:0'),
#  (3, 11): tensor(0.0018, device='cuda:0'),
#  (4, 0): tensor(0.0055, device='cuda:0'),
#  (4, 1): tensor(2.7488e-05, device='cuda:0'),
#  (4, 2): tensor(0.0112, device='cuda:0'),
#  (4, 3): tensor(0.0184, device='cuda:0'),
#  (4, 4): tensor(0.0526, device='cuda:0'),
#  (4, 5): tensor(0.0031, device='cuda:0'),
#  (4, 6): tensor(0.0468, device='cuda:0'),
#  (4, 7): tensor(0.0323, device='cuda:0'),
#  (4, 8): tensor(0.0148, device='cuda:0'),
#  (4, 9): tensor(0.0042, device='cuda:0'),
#  (4, 10): tensor(0.0025, device='cuda:0'),
#  (4, 11): tensor(0.0366, device='cuda:0'),
#  (5, 0): tensor(0.0031, device='cuda:0'),
#  (5, 1): tensor(0.0031, device='cuda:0'),
#  (5, 2): tensor(0.0024, device='cuda:0'),
#  (5, 3): tensor(0.0097, device='cuda:0'),
#  (5, 4): tensor(0.0063, device='cuda:0'),
#  (5, 5): tensor(0.3202, device='cuda:0'),
#  (5, 6): tensor(0.0194, device='cuda:0'),
#  (5, 7): tensor(0.0047, device='cuda:0'),
#  (5, 8): tensor(0.0407, device='cuda:0'),
#  (5, 9): tensor(0.2016, device='cuda:0'),
#  (5, 10): tensor(0.0769, device='cuda:0'),
#  (5, 11): tensor(0.0129, device='cuda:0'),
#  (6, 0): tensor(0.0753, device='cuda:0'),
#  (6, 1): tensor(0.0541, device='cuda:0'),
#  (6, 2): tensor(0.0250, device='cuda:0'),
#  (6, 3): tensor(0.0195, device='cuda:0'),
#  (6, 4): tensor(0.0402, device='cuda:0'),
#  (6, 5): tensor(0.0269, device='cuda:0'),
#  (6, 6): tensor(0.1427, device='cuda:0'),
#  (6, 7): tensor(0.0315, device='cuda:0'),
#  (6, 8): tensor(0.0163, device='cuda:0'),
#  (6, 9): tensor(0.2400, device='cuda:0'),
#  (6, 10): tensor(0.0025, device='cuda:0'),
#  (6, 11): tensor(0.0293, device='cuda:0'),
#  (7, 0): tensor(0.0206, device='cuda:0'),
#  (7, 1): tensor(0.0649, device='cuda:0'),
#  (7, 2): tensor(7.9963e-05, device='cuda:0'),
#  (7, 3): tensor(0.2603, device='cuda:0'),
#  (7, 4): tensor(0.0047, device='cuda:0'),
#  (7, 5): tensor(0.0269, device='cuda:0'),
#  (7, 6): tensor(0.0016, device='cuda:0'),
#  (7, 7): tensor(0.0163, device='cuda:0'),
#  (7, 8): tensor(0.0046, device='cuda:0'),
#  (7, 10): tensor(0.0046, device='cuda:0'),
#  (7, 11): tensor(0.0179, device='cuda:0'),
#  (8, 0): tensor(0.0045, device='cuda:0'),
#  (8, 1): tensor(0.0026, device='cuda:0'),
#  (8, 2): tensor(0.0761, device='cuda:0'),
#  (8, 3): tensor(0.0019, device='cuda:0'),
#  (8, 4): tensor(0.0067, device='cuda:0'),
#  (8, 5): tensor(0.0161, device='cuda:0'),
#  (8, 7): tensor(0.0119, device='cuda:0'),
#  (8, 8): tensor(0.0286, device='cuda:0'),
#  (8, 9): tensor(0.0424, device='cuda:0'),
#  (8, 11): tensor(0.0136, device='cuda:0'),
#  (9, 0): tensor(0.0150, device='cuda:0'),
#  (9, 1): tensor(0.0052, device='cuda:0'),
#  (9, 2): tensor(0.0046, device='cuda:0'),
#  (9, 3): tensor(0.0484, device='cuda:0'),
#  (9, 4): tensor(0.0218, device='cuda:0'),
#  (9, 5): tensor(0.0231, device='cuda:0'),
#  (9, 6): tensor(0.2249, device='cuda:0'),
#  (9, 7): tensor(0.2104, device='cuda:0'),
#  (9, 8): tensor(0.0498, device='cuda:0'),
#  (9, 9): tensor(0.1703, device='cuda:0'),
#  (9, 10): tensor(0.0070, device='cuda:0'),
#  (9, 11): tensor(0.0059, device='cuda:0'),
#  (10, 0): tensor(0.2710, device='cuda:0'),
#  (10, 1): tensor(0.2258, device='cuda:0'),
#  (10, 2): tensor(0.1188, device='cuda:0'),
#  (10, 3): tensor(0.0764, device='cuda:0'),
#  (10, 4): tensor(0.0290, device='cuda:0'),
#  (10, 5): tensor(0.0084, device='cuda:0'),
#  (10, 6): tensor(0.0084, device='cuda:0'),
#  (10, 8): tensor(0.0033, device='cuda:0'),
#  (10, 9): tensor(0.0017, device='cuda:0'),
#  (10, 10): tensor(0.0614, device='cuda:0'),
#  (10, 11): tensor(0.0059, device='cuda:0'),
#  (11, 0): tensor(0.0224, device='cuda:0'),
#  (11, 1): tensor(0.0767, device='cuda:0'),
#  (11, 2): tensor(0.1813, device='cuda:0'),
#  (11, 3): tensor(0.0082, device='cuda:0'),
#  (11, 4): tensor(0.0077, device='cuda:0'),
#  (11, 5): tensor(0.0297, device='cuda:0'),
#  (11, 6): tensor(0.0005, device='cuda:0'),
#  (11, 7): tensor(0.0200, device='cuda:0'),
#  (11, 8): tensor(0.0039, device='cuda:0'),
#  (11, 9): tensor(0.0614, device='cuda:0'),
#  (11, 11): tensor(0.0277, device='cuda:0')}
